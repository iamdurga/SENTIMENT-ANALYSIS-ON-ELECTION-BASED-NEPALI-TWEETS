# %% [markdown]
# ## Import

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
# !pip3 install emoji
# Out:
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.9.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, emoji, re, json
from typing import List
from string import punctuation
from sklearn.model_selection import train_test_split

# %%
CONFIGS = {'project':'transformer_model',
           'run_name':'run_21_10_2023', # run_01_01_2023
           "num_files":10,
           #'imbalance_handle':'upsample', # upsample/downsample
           "vector_size":200,
           "min_count":20,
           'window':10,
           'max_seq_length':100,
           'loss_fn':'categorical_crossentropy',
           'optimizer':'adam',
           'learning_rate':5e-5,
           'val_split':0.1,
           'bidirectional':True,
           'lstm_neurons':200,
           'classifier_actvn':'softmax',
           'max_epochs':500,
           'batch_size':32,
           'embed_dim': 128,  # Embedding size for each token
           "num_heads": 1,  # Number of attention heads
           'ff_dim': 64  # Hidden layer size in feed forward network inside transformer
           }

# %%
USE_FRESH_DATA = False

# %% [markdown]
# ## Data Handler and Loading

# %%
class DataHandler:
    def __init__(self, root: str, label_column: str, text_column: str, file_ext: str = "xlsx",
                 old_vocab='/content/drive/MyDrive/Tweet Scraping/vocab.json',
                 min_count:int=200,
                 max_word_len:int=20, min_word_needed:int=3):
        self.root = root
        self.label_column = label_column
        self.text_column = text_column
        self.file_ext = file_ext
        self.vocab = {}
        self.old_vocab_path = old_vocab
        self.min_word_needed = min_word_needed
        self.filter_words = None
        self.min_count = min_count
        self.max_word_len = max_word_len
        if old_vocab is not None:
          with open(old_vocab) as fp:
            self.vocab = json.load(fp)
            less_freq_words = [k for k,v in self.vocab.items() if v<min_count]
            huge_words = [k for k in self.vocab.keys() if len(k)>max_word_len]
            self.filter_words = less_freq_words+huge_words
            self.vocab = {k:v for k,v in self.vocab.items() if k not in self.filter_words}



    def read_files(self, number_of_files: int = 10):
        all_filenames = [file_name for file_name in os.listdir(self.root)if file_name.split(".")[-1] == self.file_ext ][:number_of_files]

        combined_df = pd.concat([pd.read_excel(os.path.join(self.root, f)) for f in all_filenames])
        self.data = combined_df
        print(f"Read {len(all_filenames)} files. Read total {len(self.data)} rows.")
        print(f"Label Counts:\n {self.data[self.label_column].value_counts()}")
        return self



    def preprocess_tweet(self, tweet:str, noise:str, stop_words:List):
        noise = list(noise)

        ntweet = emoji.replace_emoji(tweet)
        pattern = re.compile(u"[\u200c-\u200f\u202a-\u202f\u2066-\u2069]")
        ntweet = pattern.sub('', ntweet)

        nntweet = ''
        for word in ntweet.split(" "):
          if '#' not in word:
            nntweet+=" "+word

        ntweet = nntweet

        for e in noise:
          ntweet = ntweet.lower().replace(e, " ")

        ntweet = re.sub(r'''(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’]))''', " ", ntweet)
        ntweet = re.sub(r'\s', ' ', ntweet)
        tweet_token = [t.replace("\n", " ") for t in ntweet.split(" ")]
        tweet_token = [t for t in tweet_token if len(t.strip())>0]

        tweet_no_noise = tweet_token
        new_tweet = [t for t in tweet_no_noise if t not in stop_words]


        new_tweet = " ".join(new_tweet)
        new_tweet = " ".join([t for t in new_tweet.split(' ') if len(t)>1])


        if '●' in new_tweet:
          print(tweet)
          print(new_tweet)
          print("\n")

        new_tweet = new_tweet.strip()


        if self.old_vocab_path is None:
          for t in new_tweet.split(' '):
            if self.vocab.get(t) is not None:
              self.vocab[t]+=1
            else:
              self.vocab[t]=1


        return new_tweet


    def data_clean(self, stopwords_path: str,apply_filter:bool=False):
        noise = '~؟॥”▬`%´•●=+÷।–][{}*“_…‘’&#\/;@abcdefghijklmnopqrstuvwxyz1234567890०१२३४५६७८९( )-.|!?",:—?।'+"'"
        stop_file = stopwords_path
        stop_words = []
        with open(stop_file) as fp:
          lines = fp.readlines()
          stop_words = list( map(lambda x:x.strip(), lines))

        if apply_filter and len(self.filter_words)>0:
          stop_words+=self.filter_words

        self.data['clean_tokenized_text'] = self.data[self.text_column].apply(lambda x: self.preprocess_tweet(x, noise, stop_words))
        self.data = self.data.drop_duplicates(subset=['clean_tokenized_text'])


        sorted_vocab = sorted(self.vocab.items(), key=lambda x:x[1])
        self.vocab = dict(sorted_vocab)
        if apply_filter:
          if len(self.filter_words)==0:
            less_freq_words = [k for k,v in self.vocab.items() if v<self.min_count]
            huge_words = [k for k in self.vocab.keys() if len(k)>self.max_word_len]
            self.filter_words = less_freq_words+huge_words

            self.data['clean_tokenized_text'] = self.data.clean_tokenized_text.apply(lambda x: self.filter_txt(x, self.filter_words))
            self.vocab = {k:v for k,v in self.vocab.items() if k not in self.filter_words}

        self.vocab = {k:v for k,v in self.vocab.items() if k not in self.filter_words}

        self.data = self.data[self.data.clean_tokenized_text.apply(lambda x: len(x.strip(" "))>=self.min_word_needed)]
        print(f"Cleaned data: {len(self.data)}, Vocab: {len(self.vocab)}")

        return self

    def filter_txt(self, text, filter_words):
      for w in filter_words:
        text = text.replace(w,'')


      return text.strip()


    def train_test_split(self, train_ratio:float=0.8, test_ratio:float=0.1,
                         valid_ratio:float=0.1):

        data=self.data
        labels = np.array(data_handler.data.label.to_list())
        X_train, X_test, Y_train, Y_test = train_test_split(data['clean_tokenized_text'],
                                                        labels,
                                                        random_state=0, train_size=train_ratio)
        X_valid, X_test, Y_valid, Y_test = train_test_split(X_test, Y_test, train_size=valid_ratio)

        return X_train, X_test, X_valid, Y_train, Y_test, Y_valid

    def handle_imbalance(self, how="downsample", labels=[1,2]):
      temp_df = self.data[self.data.label.isin(labels)].copy()

      majority_class = temp_df.label.mode().tolist()[0]
      print(f'\nMajority class is: {majority_class}.')

      major_df = temp_df[temp_df.label==majority_class]
      minor_df = temp_df[temp_df.label!=majority_class]
      num_diff = len(minor_df)
      print(f"Majority samples: {len(major_df)} and Minority Samples: {len(minor_df)}")



      if how=='downsample':
        redf = major_df.sample(n=num_diff)
        tdf = pd.concat([redf, minor_df])
      elif how=='upsample':
        redf = minor_df.sample(n=len(major_df)-num_diff)
        tdf = pd.concat([redf, minor_df, major_df])
      else:
        print('Handling imbalance not recognized. Step skipped.')
        return self

      self.data=tdf
      print(f'After handling imbalance by {how}: {self.data.label.value_counts()}')
      return self

    def convert_label(self, kind:str='ohe', labels=[1,2], ref={1:0, 2:1}):
        self.data = self.data[self.data.label.isin(labels)]
        self.label_ref = ref
        if ref is not None:
            self.data.label = self.data.label.apply(ref.get)
        else:
            if kind=='ohe':
                ohe = {}
                for i,l in enumerate(labels):
                    ohl = np.zeros(len(labels))
                    ohl[i] = 1
                    ohe[l]=ohl
                self.data.label = self.data.label.apply(ohe.get)
        return self

    def __iter__(self):
      for i, row in self.data.iterrows():
        yield row.clean_tokenized_text.split(' ')

    # def iter_xy(self, seq_length:int=100):
    #   for i, row in self.data.iterrows():
    #     words = np.array([word2token(w) for w in row.clean_tokenized_text[:seq_length]])

    #     yield words, row.label

# %%
# import json

# with open('vocab.json', 'w', encoding='utf8') as fp:
#   json.dump(data_handler.vocab, fp,ensure_ascii=False)

# %%
data_handler = DataHandler(root='/content/drive/MyDrive/Tweet Scraping/Label', label_column='label', text_column='text', min_count=2)

# data_handler.read_files(10).convert_label().data_clean(stopwords_path= "/content/drive/MyDrive/Tweet Scraping/Resources/nepali_stop_words.txt")

# OHE for labels
# data_handler.read_files(CONFIGS['num_files']).convert_label(ref={1:[1, 0], 2:[0, 1]}).data_clean(stopwords_path= "/content/drive/MyDrive/Tweet Scraping/Resources/nepali_stop_words.txt")

#
if USE_FRESH_DATA:
  data_handler.read_files(CONFIGS['num_files']).convert_label(ref={1:0, 2:1}).data_clean(apply_filter=True,  stopwords_path= "/content/drive/MyDrive/Tweet Scraping/Resources/stop_words_nepali_25_10_2023.txt") #.handle_imbalance(labels=[0,1])
  import json
  with open('/content/drive/MyDrive/Tweet Scraping/temp_vocab.json', 'w', encoding='utf8') as fp:
    json.dump(data_handler.vocab, fp,ensure_ascii=False)

  data_handler.data.to_csv('/content/drive/MyDrive/Tweet Scraping/temp_clean_data.csv')

else:
  import json
  with open("/content/drive/MyDrive/Tweet Scraping/temp_vocab.json") as fp:
    vocab = json.load(fp)

  filtered_data = pd.read_csv("/content/drive/MyDrive/Tweet Scraping/temp_clean_data.csv")
  data_handler.data = filtered_data
  data_handler.vocab = vocab
  data_handler = data_handler.handle_imbalance(labels=[0,1], how='upsample')
# Out:
# Majority class is: 0.
# Majority samples: 45771 and Minority Samples: 27199
# After handling imbalance by upsample: 1    45771
# 0    45771
# Name: label, dtype: int64

# %%
# purge max repeated words
num_max_repeated_words = 100000
max_repeated_words = [k for k,v in data_handler.vocab.items() if v>num_max_repeated_words]
filtered_data = data_handler.data.copy()
new_vocab = {k:v for k, v in data_handler.vocab.items() if k not in max_repeated_words}
filtered_data['clean_tokenized_text'] = filtered_data.clean_tokenized_text.apply(lambda x: data_handler.filter_txt(x, max_repeated_words))

# %%
filtered_data = filtered_data[filtered_data.clean_tokenized_text.apply(lambda x: len(x.split(' ')))>1]

# %% [markdown]
# ### Vocab
# Legth of vocab and least/most popular vocab.

# %%
vocab = new_vocab #data_handler.vocab
print(f"Total number of words in vocabulary: {len(vocab)}")
# Out:
# Total number of words in vocabulary: 48832

# %%
vdf = pd.DataFrame([[k, v] for k, v in vocab.items()] , columns=['word', 'counts'], index = np.arange(len(vocab)))
vdf = vdf.sort_values('counts')
vdf
# Out:
#             word  counts
# 0       शाहहरुको       2
# 10503   पंचायतका       2
# 10504  ग्यांगलाई       2
# 10505   मैवाखोला       2
# 10506    दुहुँमा       2
# ...          ...     ...
# 48827      देउवा    6047
# 48828       मेयर    6274
# 48829     नेपाली   10864
# 48830   निर्वाचन   12482
# 48831        भोट   16304
#
# [48832 rows x 2 columns]

# %%
fname = ['nepali_stop_words.txt', 'NLP_stop_words.txt', 'stop_words_nepali_25_10_2023.txt'][2]
with open('/content/drive/MyDrive/Tweet Scraping/Resources/'+fname) as fp:
  stop_words = [s.strip() for s in fp.readlines()]

# %% [markdown]
# ### How many times certain word repeated in Negative/Positive class?

# %%
vocab_class = {1:{}, 0:{}}
vocab_words = list(vocab.keys())

for i, row in filtered_data.iterrows():
  vc=vocab_class[row.label]

  for word in row.clean_tokenized_text.split(" "):
    if vc.get(word) is None:
      vc[word]=1
    else:
      vc[word]+=1
  vocab_class[row.label].update(vc)
  # if i>100:
  #   break

# %%
vocab_class
# Out:
# {1: {'सत्तारुढ': 254,
#   'गठबन्धनले': 276,
#   'दलीय': 117,
#   'गठबन्धन': 1782,
#   'बाहिरका': 22,
#   'दलसँग': 19,
#   'चुनावी': 714,
#   'तालमेल': 204,
#   'खारेज': 485,
#   'निर्णय': 316,
#   'भोट': 10904,
#   'फलानो': 74,
#   'चिन्हमा': 158,
#   'सुनियो': 50,
#   'मतपत्र': 333,
#   'जानकारि': 5,
#   'ज्यादै': 6,
#   'न्युन': 6,
#   'पाइयो': 41,
#   'कलंकी': 6,
#   'आशै': 2,
#   'नगरे': 102,
#   'स्थापित': 407,
#   'बाले': 74,
#   'जमानामा': 22,
#   'उती': 2,
#   'उफ्रेका': 7,
#   'मतगणना': 232,
#   'सकिएपछि': 23,
#   'घाममा': 41,
#   'सुत्ने': 18,
#   'गयो': 178,
#   'पालो': 122,
#   'बुढाको': 9,
#   'देख्यौ': 10,
#   'जनताले': 986,
#   'हाले': 258,
#   'कम्युनिस्ट': 270,
#   'राप्रपा': 911,
#   'माग्ने': 305,
#   'अधक्ष्य': 8,
#   'हुदै': 95,
#   'कांग्रेसलाइ': 15,
#   'हाल्न': 848,
#   'हालेर': 310,
#   'राजा': 296,
#   'चाहियो': 106,
#   'पातकी': 12,
#   'बहुरुपी': 4,
#   'हुनुभन्दा': 12,
#   'कांग्रेस': 2482,
#   'हाल्ने': 634,
#   'गर्व': 24,
#   'गर्नुस': 100,
#   'माग्न': 631,
#   'आउँदा': 76,
#   'वर्षलाई': 4,
#   'आउ': 63,
#   'तिहारमा': 25,
#   'नाचगान': 33,
#   'यीनले': 21,
#   'हसियाँ': 16,
#   'हतौडा': 44,
#   'पर्यो': 472,
#   'हात': 343,
#   'काट्छु': 13,
#   'बिचरा': 162,
#   'गरुन्': 23,
#   'राजनिति': 102,
#   'ब्यापार': 24,
#   'कार्यकर्ताले': 320,
#   'दलित': 119,
#   'बस्तीमा': 19,
#   'बाँड्न': 34,
#   'लागेका': 157,
#   'मदिरा': 74,
#   'चामल': 23,
#   'प्रहरीद्वारा': 19,
#   'जफत': 112,
#   'केशव': 261,
#   'नहाल्ने': 101,
#   'मान्छे': 1060,
#   'नर्क': 45,
#   'जान्छ': 329,
#   'आर्यघाट': 28,
#   'देख्यो': 14,
#   'मरु': 18,
#   'लाग्छ': 644,
#   'भनेपछि': 115,
#   'हाल्यो': 57,
#   'मर्न': 29,
#   'मन': 648,
#   'हालेन': 36,
#   'टोइट': 4,
#   'सिन्धुली': 11,
#   'उदयपुर': 7,
#   'खोटाङ': 6,
#   'लगायतका': 37,
#   'जिल्लामा': 103,
#   'उम्मेदवारी': 2488,
#   'नेशनल': 2,
#   'अर्गनाईजेसन': 2,
#   'जातिय': 42,
#   'पाटी': 141,
#   'धुलो': 65,
#   'पिठो': 9,
#   'भएछ': 239,
#   'काहीँ': 11,
#   'सुनिन्न': 4,
#   'मासुभात': 77,
#   'बिकेका': 9,
#   'नेपाली': 5134,
#   'सर्व': 6,
#   'साधारण': 83,
#   'नागरिकहरूलाई': 3,
#   'सेवा': 109,
#   'घुस': 47,
#   'खाएर': 174,
#   'हैसियत': 154,
#   'बनाएका': 70,
#   'भेषमा': 11,
#   'आम': 169,
#   'समाजलाई': 14,
#   'अपमान': 154,
#   'गरिरहेछन': 10,
#   'प्रवृत्तिलाई': 10,
#   'दण्डित': 19,
#   'छोडेर': 161,
#   'घमण्ड': 62,
#   'मेयर': 2686,
#   'साब': 79,
#   'नजिकिए': 2,
#   'देउवा': 4109,
#   'पौडेल': 311,
#   'कोइराला': 86,
#   'निधि': 10,
#   'असन्तुष्ट': 47,
#   'मेयरको': 142,
#   'पदमा': 278,
#   'भूपू': 18,
#   'प्रधानमन्त्रीको': 102,
#   'छोरीलाइ': 15,
#   'जिताउन': 228,
#   'राज्यशक्ती': 5,
#   'संयन्त्र': 24,
#   'स्रोत': 47,
#   'साधनको': 13,
#   'बर्तमान': 37,
#   'प्रधानमन्त्री': 1518,
#   'दुरुपयोग': 148,
#   'ठुलो': 272,
#   'अनैतिक': 51,
#   'भ्रष्ट': 270,
#   'व्यबहार': 17,
#   'उम्मेद्वारलाइ': 5,
#   'दिनु': 525,
#   'जनताको': 651,
#   'दुर्दशा': 12,
#   'निम्त्याउनु': 5,
#   'अमेरिकामा': 44,
#   'मूलका': 8,
#   'आइत': 8,
#   'गुरुङ': 51,
#   'पत्नी': 124,
#   'हत्यामा': 7,
#   'दोषी': 64,
#   'ठहर': 30,
#   'आफूहरूसँग': 2,
#   'सम्झौता': 58,
#   'कार्यान्वयन': 68,
#   'नगरेको': 93,
#   'तराई': 34,
#   'मधेस': 59,
#   'जनता': 1543,
#   'पार्टी': 2355,
#   'टाइगर्स': 8,
#   'प्रतिनिधिसभा': 310,
#   'प्रदेशसभा': 258,
#   'निर्वाचन': 5221,
#   'बहिष्कार': 173,
#   'भेडाहरुले': 23,
#   'बिरोध': 242,
#   'खतिवडाले': 8,
#   'झापड': 63,
#   'खाए': 75,
#   'रमाउदै': 2,
#   'इस्वर': 6,
#   'पोख्रेलले': 9,
#   'गोलि': 27,
#   'खान': 222,
#   'कोरोनाको': 7,
#   'सबैभन्दा': 204,
#   'भ्रष्टाचार': 373,
#   'गणतन्त्र': 696,
#   'संघीयता': 101,
#   'धर्मनिरपेक्षता': 29,
#   'बनाउनको': 5,
#   'तल्लीन': 4,
#   'ठान्ने': 32,
#   'शक्तीको': 2,
#   'खेल': 185,
#   'समाप्त': 116,
#   'पार्न': 140,
#   'चाहानछन': 2,
#   'वर्षअघि': 10,
#   'सक्रिय': 52,
#   'राजनीतिमा': 268,
#   'उम्मेदवार': 1775,
#   'नेत्री': 26,
#   'सिंह': 165,
#   'पहिलोपटक': 25,
#   'जिम्मेवारी': 79,
#   'चुनौतीपूर्ण': 19,
#   'आकांक्षी': 4,
#   'बनेकी': 12,
#   'छिन्': 45,
#   'उम्मेदवारहरू': 27,
#   'उनीमाथि': 14,
#   'गम्भीर': 136,
#   'आरोप': 519,
#   'लगाउने': 214,
#   'ठाउँ': 192,
#   'पाएका': 93,
#   'भरतपुरमा': 282,
#   'रेणुलाई': 58,
#   'जिताउने': 179,
#   'प्रचण्डको': 290,
#   'पिरती': 22,
#   'चल्नेवाला': 9,
#   'सुरेन्द्र': 37,
#   'पाण्डे': 70,
#   'गनेका': 8,
#   'फर्सीको': 2,
#   'मुन्टा': 8,
#   'केलाका': 8,
#   'बेर': 87,
#   'लगाका': 7,
#   'केटा': 52,
#   'मतदाता': 668,
#   'उल्लु': 29,
#   'हँ': 56,
#   'चुनाव': 2630,
#   'जिताएर': 83,
#   'मान्ने': 95,
#   'बनाएर': 264,
#   'पठाएको': 25,
#   'मान्छेलाई': 106,
#   'बाटो': 219,
#   'घाटो': 4,
#   'कुलो': 4,
#   'स्कुल': 32,
#   'धारा': 24,
#   'पौवा': 3,
#   'पुल': 23,
#   'मन्दिर': 26,
#   'बनाउन': 442,
#   'लाउनी': 11,
#   'बिहे': 87,
#   'बर्तमन': 2,
#   'छेवर': 2,
#   'न्वारन': 3,
#   'बोलाएर': 24,
#   'खाम': 5,
#   'पठाएपछि': 10,
#   'चुप': 117,
#   'मानेर': 49,
#   'बस्नु': 106,
#   'क्षेत्रीय': 25,
#   'सभापति': 914,
#   'केपी': 657,
#   'ओलीले': 321,
#   'मुखले': 52,
#   'माग्नुहुन्छ': 3,
#   'राष्ट्रको': 55,
#   'बराबर': 64,
#   'मान्छेको': 86,
#   'भाषण': 230,
#   'मलेसियामा': 15,
#   'जाउ': 63,
#   'दिदी': 81,
#   'टिकट': 640,
#   'काटेको': 18,
#   'बागमती': 40,
#   'काटेर': 60,
#   'चाबेल': 6,
#   'जानु': 106,
#   'पुलमा': 5,
#   'जाममा': 2,
#   'पर्दा': 93,
#   'ठ्याकै': 4,
#   'लागो': 21,
#   'परिवारको': 38,
#   'रुवाबासि': 6,
#   'परिवार': 145,
#   'टिकटको': 22,
#   'अचार': 29,
#   'बनाइयो': 20,
#   'सरकार': 956,
#   'नदेखिने': 5,
#   'बनाऊ': 10,
#   'पाइन': 16,
#   'मध्यराती': 2,
#   'पैसा': 1117,
#   'बाढ्दै': 11,
#   'नेताहरु': 247,
#   'रंगेहात': 14,
#   'समातिए': 7,
#   'झन्डा': 119,
#   'बोक्ने': 105,
#   'झगडा': 86,
#   'नारा': 206,
#   'बिकास': 248,
#   'न्याय': 115,
#   'भस्टचार': 10,
#   'उत्साहका': 4,
#   'निर्वाचनमा': 563,
#   'होमिएका': 14,
#   'सत्तारूढ': 73,
#   'परिणाम': 297,
#   'ल्याउन': 110,
#   'सकेनन्': 98,
#   'अनपेक्षित': 12,
#   'मत': 1427,
#   'परिणामका': 3,
#   'गठबन्धनबीच': 14,
#   'माओवादी': 2032,
#   'एकीकृत': 203,
#   'समाजवादीका': 72,
#   'नेताले': 311,
#   'वाम': 33,
#   'एकताका': 2,
#   'भित्रभित्र': 3,
#   'एमालेसँग': 66,
#   'सम्पर्क': 31,
#   'बढाइरहेका': 2,
#   'नेपालको': 467,
#   'संधियता': 2,
#   'पाटि': 69,
#   'आफना': 4,
#   'कार्यकर्ता': 697,
#   'पाल्न': 20,
#   'संघियताको': 14,
#   'आबस्यकता': 7,
#   'संघियता': 62,
#   'सन्दर्भमा': 25,
#   'आबस्यक': 6,
#   'केबल': 25,
#   'राजनीति': 1025,
#   'दलका': 318,
#   'बेबस्थापन': 2,
#   'भएकोे': 5,
#   'लाग्दैन': 237,
#   'समितिले': 23,
#   'सिफारिस': 54,
#   'व्यक्तिलाई': 92,
#   'बनाएको': 182,
#   'कारणले': 80,
#   'पौडेलले': 128,
#   'राजीनामा': 1299,
#   'गठबन्धनलाई': 202,
#   'स्थिर': 21,
#   'बन्छ': 143,
#   'एमालेलाई': 335,
#   'जनतालाई': 446,
#   'राम्रोसँग': 44,
#   'बनेको': 182,
#   'नबुझ्ने': 26,
#   'होइनन्': 124,
#   'भोलि': 282,
#   'पर्सी': 10,
#   'कम्प्लेन': 2,
#   'पाइन्छ': 132,
#   'नाई': 68,
#   'भएपछि': 335,
#   'सर्वोच्च': 92,
#   'गएका': 122,
#   'रुपन्देही': 62,
#   'सदस्यमा': 68,
#   'पार्टीको': 752,
#   'चिन्ह': 325,
#   'लौरो': 299,
#   'गराएका': 36,
#   'कमल': 243,
#   'भुसाल': 66,
#   'मुद्दामा': 50,
#   'अदालतले': 89,
#   'अन्तरिम': 49,
#   'आदेश': 116,
#   'अस्वीकार': 61,
#   'व्याख्या': 10,
#   'गर्नुहोस': 36,
#   'यु': 14,
#   'आर': 16,
#   'नाइस': 2,
#   'लेडी': 11,
#   'थुतुनो': 81,
#   'मेरी': 32,
#   'छोरीले': 72,
#   'हारे': 273,
#   'देशमा': 597,
#   'संकट': 34,
#   'आउने': 501,
#   'मेरा': 85,
#   'मेयरले': 64,
#   'हारेको': 109,
#   'ठाउमा': 106,
#   'बजेट': 286,
#   'बिनियोजन': 5,
#   'थु': 17,
#   'लागेछी': 2,
#   'तिम्राे': 11,
#   'मेराे': 38,
#   'काट्नै': 2,
#   'छाेडे': 2,
#   'होईन': 384,
#   'लोकतन्त्र': 326,
#   'भएकैले': 7,
#   'अपूर्व': 10,
#   'सिंहको': 43,
#   'रिहाई': 6,
#   'सामाजिक': 262,
#   'संजालको': 7,
#   'राज्यलाई': 10,
#   'राजाको': 70,
#   'शासन': 158,
#   'हुँदो': 21,
#   'जेलमा': 45,
#   'बोक्नेलाई': 2,
#   'सुन्दर': 87,
#   'व्यवस्था': 305,
#   'लाग्नेले': 2,
#   'व्यवस्थाको': 29,
#   'गन्नु': 14,
#   'दाई': 138,
#   'दाईको': 21,
#   'भाई': 130,
#   'मधेसी': 102,
#   'आयोगले': 700,
#   'काठमाडौं': 519,
#   'महानगरपालिकाका': 55,
#   'बालेन्द्र': 332,
#   'साहविरुद्ध': 8,
#   'नाराबाजी': 35,
#   'भिडियोमा': 10,
#   'समुदायमाथि': 2,
#   'अपमानजनक': 12,
#   'शब्द': 153,
#   'प्रयोग': 476,
#   'गरिएको': 307,
#   'संलग्नलाई': 2,
#   'कारबाही': 502,
#   'मन्त्रालय': 38,
#   'प्रहरीलाई': 32,
#   'आग्रह': 92,
#   'माेहन': 8,
#   'वैध': 6,
#   'कमरेड': 767,
#   'किरण': 18,
#   'नेतृत्वको': 162,
#   'क्रान्तिकारी': 72,
#   'माअाेवादि': 11,
#   'निकट': 43,
#   'देशभक्त': 31,
#   'जनतान्त्रिक': 2,
#   'माेर्चा': 4,
#   'नेपालले': 95,
#   'अासन्न': 4,
#   'पुर्ण': 39,
#   'ऐक्यबद्धता': 4,
#   'जाहेर': 12,
#   'गर्दछौं': 15,
#   'अष्ट्रेलिया': 10,
#   'चेलीको': 2,
#   'नाममा': 414,
#   'शरीर': 15,
#   'विज्ञापन': 14,
#   'भुइँकटर': 15,
#   'देको': 70,
#   'लाजै': 18,
#   'मर्दो': 9,
#   'विवेकशीलका': 5,
#   'डाडुमा': 13,
#   'पानी': 315,
#   'तताउदै': 4,
#   'सुर्खेतमा': 75,
#   'काँग्रेस': 553,
#   'कार्यकर्ताबीच': 395,
#   'झडप': 541,
#   'हथौडा': 54,
#   'कलम': 103,
#   'छातामा': 6,
#   'नबोल्या': 2,
#   'बेस': 32,
#   'धराने': 36,
#   'प्रिय': 41,
#   'सहि': 261,
#   'गलत': 503,
#   'सालमै': 9,
#   'विदेशमा': 54,
#   'नेपालीले': 68,
#   'हालेका': 40,
#   'पाउँदैनन्': 17,
#   'वर्षसम्म': 44,
#   'कानुन': 200,
#   'चासो': 74,
#   'देखायो': 36,
#   'संसदले': 19,
#   'दबाब': 76,
#   'दियो': 156,
#   'फलतः': 3,
#   'आसन्न': 67,
#   'चुनावमा': 849,
#   'संख्यामा': 26,
#   'मताधिकारबाट': 10,
#   'बाहिरै': 7,
#   'रहनेछन्': 3,
#   'बेपार': 4,
#   'एकअर्कालाई': 24,
#   'फटहा': 12,
#   'गालि': 75,
#   'उहिले': 32,
#   'कांग्रेसी': 122,
#   'उफ्रिन्छन': 5,
#   'रहनु': 43,
#   'गठबन्धनको': 369,
#   'आफ्ना': 260,
#   'उनकी': 15,
#   'छोरीको': 36,
#   'चिन्ता': 251,
#   'लाग्नु': 76,
#   'कांग्रेसका': 653,
#   'दुर्भाग्य': 72,
#   'ठाउँको': 27,
#   'भोटर': 134,
#   'जानकारी': 135,
#   'आयोगलाइ': 12,
#   'राष्ट्रिय': 401,
#   'परिचयपत्र': 54,
#   'कर्पोरेट': 4,
#   'सिम': 9,
#   'बैंकमा': 3,
#   'निजी': 50,
#   'नम्वर': 15,
#   'राखेको': 99,
#   'आयोगलाई': 98,
#   'औँला': 7,
#   'कस्लाइ': 25,
#   'भन्नुस': 27,
#   'पाउमा': 40,
#   'हजारका': 8,
#   'नोट': 183,
#   'चढाउँदै': 6,
#   'माग्दै': 226,
#   'पद': 336,
#   'तुच्छ': 28,
#   'यिनको': 140,
#   'छोरा': 132,
#   'छोरी': 330,
#   'स्वास्नीलाई': 10,
#   'दिलाउन': 19,
#   'हदै': 13,
#   'गिर्दै': 4,
#   'दलालहरुलाई': 14,
#   'हेपेर': 9,
#   'जहानीया': 2,
#   'चलाउन': 104,
#   'कैलेसम्म': 2,
#   'विजय': 100,
#   'शाहीलाई': 8,
#   'देशैभरि': 6,
#   'मतगणनामा': 26,
#   'ढिलाई': 4,
#   'कम्युनिस्टको': 25,
#   'गढ': 16,
#   'गण्डकीमा': 10,
#   'कित्तामा': 9,
#   'नतिजा': 202,
#   'वालिङ': 31,
#   'वडाध्यक्ष': 787,
#   'किसान': 26,
#   'न्यौपाने': 9,
#   'पराजुली': 11,
#   'लक्ष्मी': 20,
#   'घाइते': 376,
#   'काङ्ग्रेस': 1027,
#   'डेमोक्रेसी': 6,
#   'बरिस्ठ': 19,
#   'छाडेर': 74,
#   'नियुक्ति': 63,
#   'गरो': 26,
#   'डाक्टर': 52,
#   'सायप': 4,
#   'युवालाइ': 15,
#   'बेचेर': 99,
#   'उनिहरुकै': 7,
#   'रेमिट्यान्स': 10,
#   'चलाएर': 31,
#   'अन्तत': 18,
#   'उनिहरुलाई': 22,
#   'बन्चित': 29,
#   'गराउने': 171,
#   'चलन': 43,
#   'सन्सारमा': 5,
#   'बालेन': 870,
#   'जित': 197,
#   'हार': 208,
#   'राजनिती': 198,
#   'परिदृश्य': 5,
#   'सुरुवात': 30,
#   'जितेको': 162,
#   'खण्डमा': 16,
#   'दलले': 206,
#   'बैंक': 123,
#   'दास': 187,
#   'परिभाषामा': 6,
#   'आगोले': 5,
#   'जिल्ला': 302,
#   'सासन': 13,
#   'युगको': 9,
#   'आगामी': 144,
#   'बिबेक': 24,
#   'आआफ्नो': 9,
#   'जिल्लामै': 12,
#   'थन्काएर': 4,
#   'आफु': 152,
#   'दौडाहामा': 10,
#   'गोर्खामा': 21,
#   'प्रचण्ड': 1593,
#   'कैद': 29,
#   'डडेलधुरामा': 44,
#   'रौतहटमा': 20,
#   'माधब': 65,
#   'गठेहरु': 9,
#   'जीत': 69,
#   'सुनिस्चित': 13,
#   'छोड्न': 40,
#   'सकेका': 65,
#   'बास्तबमा': 3,
#   'हारिसकेका': 3,
#   'पार्टि': 133,
#   'चरणमा': 24,
#   'दिनानुदिन': 12,
#   'सिद्धान्तहिन': 4,
#   'अलोकतान्त्रिक': 14,
#   'बृद्धि': 3,
#   'जारि': 10,
#   'रहेकाले': 8,
#   'क्रियाकलापको': 4,
#   'किनारा': 9,
#   'साक्षी': 16,
#   'बस्नुको': 5,
#   'आजैका': 2,
#   'मितिदेखि': 3,
#   'कांग्रेसको': 479,
#   'सदस्यता': 43,
#   'परित्याग': 95,
#   'अठोट': 13,
#   'जय': 410,
#   'महंगो': 20,
#   'आयोग': 705,
#   'अनुसन्धान': 48,
#   'विभाग': 14,
#   'गाडी': 197,
#   'देख्दै': 10,
#   'उपाय': 44,
#   'गरीब': 39,
#   'धनी': 36,
#   'स्वस्थ': 17,
#   'आलोचना': 83,
#   'मित्रवत': 3,
#   'प्रतिस्पर्धा': 221,
#   'राजनीतिक': 654,
#   'संस्कारको': 9,
#   'अवसान': 13,
#   'भएकोहो': 2,
#   'माधव': 364,
#   'लिएपछि': 21,
#   'कुल्ला': 23,
#   'खप्र': 2,
#   'ओली': 1405,
#   'नजिते': 119,
#   'मुलुक': 136,
#   'दुर्घटनामा': 469,
#   'पुग्छ': 86,
#   'धम्की': 291,
#   'हारेका': 31,
#   'पालिकामा': 91,
#   'दिन्न': 89,
#   'आरजुको': 31,
#   'अभिव्यक्तिमा': 7,
#   'मौन': 385,
#   'घोषणापत्र': 201,
#   'समाचार': 231,
#   'एउटैले': 2,
#   'ड्राफ्ट': 4,
#   'संसद्को': 4,
#   'सिटमा': 56,
#   'दुईतिहाई': 8,
#   'सांसद': 299,
#   'संविधान': 224,
#   'संशोधनको': 3,
#   'लेखेको': 89,
#   'पुष्पकमलको': 6,
#   'पाठकलाई': 11,
#   'ठग्न': 10,
#   'मिल्छ': 150,
#   'एमालेको': 561,
#   'घोषणा': 391,
#   'पत्रमा': 60,
#   'कारिन्दा': 12,
#   'पत्रिकाको': 4,
#   'हेडलाइन': 10,
#   'भुसालको': 25,
#   'हुदैछ': 77,
#   'नियोजित': 11,
#   'हुँदैछ': 63,
#   'तोसिमाको': 19,
#   'फाईदाको': 3,
#   'भैरहेको': 41,
#   'तेसो': 32,
#   'हार्न': 51,
#   'भाशा': 2,
#   'नबोलौ': 4,
#   'जितोस': 40,
#   'पत्ता': 101,
#   'साफ': 80,
#   'शालमा': 4,
#   'देउवालाई': 171,
#   'बुझाएको': 18,
#   'ज्ञापन': 7,
#   'पत्र': 217,
#   'निर्दोष': 22,
#   'नागरिकको': 61,
#   'हत्या': 314,
#   'विर्सिदिनु': 3,
#   'आइज': 12,
#   'आफन्त': 33,
#   'छोरीलाई': 119,
#   'राज्य': 177,
#   'लुट्ने': 77,
#   'पुर्याउन': 38,
#   'विचारहरु': 5,
#   'बिर्सनु': 9,
#   'ज्यानमारा': 27,
#   'हत्यारा': 104,
#   'सिर्जना': 192,
#   'गगन': 500,
#   'विश्वप्रकाश': 39,
#   'देखिनु': 14,
#   'कमजोर': 243,
#   'सक्दैनन': 40,
#   'हिन्दु': 57,
#   'संगठित': 23,
#   'नभएकै': 10,
#   'खास': 70,
#   'आवरण': 4,
#   'हिन्दुको': 4,
#   'ईण्डिया': 6,
#   'चाईना': 5,
#   'अमेरिका': 97,
#   'युरोप': 26,
#   'मिल्न': 28,
#   'सक्दैनन्': 87,
#   'एकदिन': 16,
#   'दुइचार': 4,
#   'हातमा': 151,
#   'भरमा': 103,
#   'बर्ष': 581,
#   'दुःख': 87,
#   'सहन': 24,
#   'सम्मको': 68,
#   'अबुझ': 13,
#   'भेडा': 270,
#   'छुट्याउन': 25,
#   'हुनुहोस': 5,
#   'निधो': 6,
#   'स्थापितलाइ': 6,
#   'महिला': 456,
#   'वाला': 162,
#   'पर्नुभो': 5,
#   'लोकल': 14,
#   'चाहिएको': 65,
#   'गाउँ': 250,
#   'घरको': 52,
#   'आबश्यकता': 9,
#   'बुझ्ने': 86,
#   'अन्तरक्रियात्मक': 2,
#   'भेटघाट': 7,
#   'तपैं': 4,
#   'घरमा': 244,
#   'मानिस': 107,
#   'उठबस': 4,
#   'हिँडेका': 56,
#   'हरुलाई': 123,
#   'सम्झाई': 4,
#   'दिउँ': 47,
#   'छिट्टै': 27,
#   'ब्यवस्था': 66,
#   'मासिने': 7,
#   'गरिको': 5,
#   'हर्कत': 77,
#   'नगर्न': 69,
#   'पोखरा': 83,
#   'महानगरपालिकामा': 34,
#   'आउँदो': 19,
#   'वर्षका': 17,
#   'जनप्रतिनिधि': 296,
#   'बन्ने': 278,
#   'आशमा': 11,
#   'पार्टीबाट': 172,
#   'बहालवाला': 35,
#   'पदबाट': 144,
#   'अधिकांशले': 8,
#   'बुढानिलकण्ठ': 22,
#   'नगरपालिका': 878,
#   'आफुलाइ': 44,
#   'सुरक्षित': 90,
#   'अस्तित्व': 87,
#   'बचाउन': 60,
#   'दौडधुप': 18,
#   'गरिरहेछ': 5,
#   'पासा': 9,
#   'प्रबल': 7,
#   'संभावना': 64,
#   'छाडेको': 15,
#   'चाकरी': 22,
#   'सक्काउन': 13,
#   'खोजे': 48,
#   'गरिहाल्छन': 2,
#   'सुरा': 4,
#   'रैछन': 85,
#   'देउवाको': 305,
#   'तलुवा': 25,
#   'चाट्ने': 8,
#   'बनेनन': 5,
#   'देखाउछन': 7,
#   'मन्त्रीको': 36,
#   'विवाद': 98,
#   'अधिकृत': 159,
#   'फेरिए': 10,
#   'आचारसंहिताको': 78,
#   'उल्लंघन': 237,
#   'स्थायी': 36,
#   'शिक्षक': 35,
#   'कर्मचारी': 125,
#   'प्रचारमा': 124,
#   'अायोगले': 5,
#   'बिग्रेको': 35,
#   'सिस': 4,
#   'चेक': 35,
#   'भन्नू': 175,
#   'प्रभु': 37,
#   'मिलेर': 310,
#   'लुट्छन्': 2,
#   'नामै': 21,
#   'केन्द्र': 256,
#   'विस्तारित': 4,
#   'केन्द्रित': 33,
#   'लास्टमा': 42,
#   'पुष्पकमल': 152,
#   'नातेदार': 13,
#   'हुक्के': 5,
#   'बाँकी': 285,
#   'देशको': 652,
#   'हितमा': 38,
#   'दल': 1011,
#   'नियम': 125,
#   'जाँदै': 43,
#   'रुख': 296,
#   'चिन्हबाट': 12,
#   'उठेर': 77,
#   'मतदान': 964,
#   'लाउछु': 3,
#   'भुइँकटहरमा': 10,
#   'सिमित': 44,
#   'हुनुपर्यो': 15,
#   'दलको': 370,
#   'चुनाब': 514,
#   'हाल्छु': 46,
#   'नदिएर': 56,
#   'त्याहा': 6,
#   'जन्ता': 60,
#   'गन्न': 92,
#   'चाहिन्न': 8,
#   'सल्लाह': 34,
#   'शेर': 416,
#   'बहादुर': 425,
#   'हराउनै': 21,
#   'हल्ला': 122,
#   'चुनावताका': 3,
#   'कार्यक्रममा': 86,
#   'रिस': 105,
#   'मिटु': 6,
#   'विषयमा': 113,
#   'नसक्नु': 56,
#   'कांग्रेसकी': 25,
#   'उम्मेदवारको': 313,
#   'अहिलेसम्म': 136,
#   'देखिएको': 101,
#   'बालन': 8,
#   'शाहले': 84,
#   'मौकामा': 12,
#   'चौका': 5,
#   'हान्न': 59,
#   'सक्लान्': 8,
#   'सिस्टम': 36,
#   'चेतनशिल': 4,
#   'नीयम': 2,
#   'गतिलो': 102,
#   'गधा': 73,
#   'चुनेको': 8,
#   'गधाले': 9,
#   'विकास': 297,
#   'भेडालाई': 8,
#   'दिउसै': 8,
#   'सपना': 207,
#   'देखाको': 10,
#   'भाग': 166,
#   'स्थानिय': 226,
#   'स्वतन्त्र': 1226,
#   'नराम्रो': 105,
#   'स्थिति': 89,
#   'गरिब': 112,
#   'सिंगापुर': 20,
#   'पाएको': 145,
#   'स्थान': 70,
#   'पुग्यो': 85,
#   'तन': 4,
#   'झर्यो': 5,
#   'ठिक': 292,
#   'सम्हालेर': 7,
#   'आफुले': 131,
#   'बोलेको': 108,
#   'शक्ति': 207,
#   'राजाहरु': 6,
#   'बागी': 429,
#   'निष्कृय': 32,
#   'महिनावारीमा': 5,
#   'बिदा': 115,
#   'बढाएर': 13,
#   'क्षेत्रमा': 240,
#   'महिलालाई': 59,
#   'लिन्छु': 19,
#   'बकम्फुसे': 23,
#   'प्रतिवद्धता': 26,
#   'मैत्री': 13,
#   'समाजकाे': 2,
#   'विपरित': 61,
#   'जनप्रतिनिधी': 36,
#   'ज्यूहरुले': 2,
#   'हार्ने': 201,
#   'डरले': 87,
#   'धाकधम्कीमा': 11,
#   'उत्रियो': 12,
#   'नेपालका': 200,
#   'महेन्द्रलाई': 4,
#   'पुज्छन': 2,
#   'हिसिला': 8,
#   'पुर्ब': 53,
#   'बाबुराम': 212,
#   'लेन्डुपे': 4,
#   'तेसैले': 51,
#   'मुखुन्डो': 2,
#   'धारि': 4,
#   'पेट': 34,
#   'गाउँबाट': 9,
#   'सहर': 51,
#   'पस्नु': 4,
#   'गाउँमा': 119,
#   'बस्न': 144,
#   'नमिल्ने': 80,
#   'जनप्रतिनिधीलाई': 4,
#   'सहरबाट': 5,
#   'पुग्नुपर्ने': 10,
#   'बाध्यता': 55,
#   'कांग्रेसले': 463,
#   'भातृ': 10,
#   'संगठनहरूको': 2,
#   'महाधिवेशन': 49,
#   'स्थगित': 232,
#   'निर्देशन': 140,
#   'मानसिक': 49,
#   'विचलन': 7,
#   'भइसकेको': 39,
#   'नेकपा': 989,
#   'एककृत': 2,
#   'माक्सवादी': 4,
#   'लेनिनवादी': 2,
#   'हटाई': 10,
#   'पुरा': 131,
#   'सिद्धान्त': 165,
#   'रामदेव': 5,
#   'बाबाको': 9,
#   'अवतारको': 5,
#   'प्रतिक': 7,
#   'शा': 6,
#   'अन्ध': 6,
#   'बिश्वासको': 4,
#   'आधारमा': 227,
#   'लडि': 4,
#   ...},
#  0: {'मानव': 81,
#   'अधिकार': 217,
#   'लोकतान्त्रिक': 276,
#   'शासन': 109,
#   'व्यवस्थाको': 26,
#   'अभिन्न': 5,
#   'अंग': 4,
#   'प्रम': 192,
#   'देउवा': 2693,
#   'अधिकारलाई': 9,
#   'केन्द्रविन्दुमा': 4,
#   'राख्दै': 43,
#   'प्रधानमन्त्री': 1496,
#   'सरकारका': 32,
#   'नीतिमा': 9,
#   'आइएको': 3,
#   'अङ्ग': 6,
#   'जिते': 405,
#   'शेरबहादुर': 538,
#   'अर्जेन्टिनाले': 1,
#   'केपी': 470,
#   'ओली': 784,
#   'फ्रान्सले': 1,
#   'प्रचण्ड': 787,
#   'माधव': 247,
#   'राचपौ': 3,
#   'गगन': 330,
#   'थापा': 531,
#   'रवी': 21,
#   'लामिछाने': 87,
#   'सिके': 40,
#   'राउत': 33,
#   'योग': 6,
#   'सदस्यीय': 31,
#   'भविष्यवाणी': 10,
#   'छः': 29,
#   'जितेर': 161,
#   'खुसी': 139,
#   'भएपनि': 114,
#   'भोली': 98,
#   'बिहान': 162,
#   'उठ्दा': 12,
#   'रहन्छन्': 9,
#   'केन्द्रबिन्दुमा': 2,
#   'हसाउनुहुन्छ': 2,
#   'पौडेल': 301,
#   'सर': 278,
#   'नहुन्': 1,
#   'नेपालीको': 93,
#   'चाहना': 50,
#   'भन्यो': 107,
#   'हजुरको': 83,
#   'चित्त': 62,
#   'दुख्ला': 3,
#   'राजनीति': 520,
#   'जीवनको': 30,
#   'भएकोले': 64,
#   'थापालाई': 83,
#   'बन्न': 204,
#   'सघाउनुस्': 2,
#   'त्यसैमा': 15,
#   'काँग्रेस': 559,
#   'दुबैको': 11,
#   'भलो': 37,
#   'पिछडिएको': 13,
#   'बर्ग': 17,
#   'समानुपातिक': 247,
#   'सभासद्': 4,
#   'आरजु': 141,
#   'राणा': 107,
#   'मदेशी': 2,
#   'समुदाय': 37,
#   'विमलेन्द्र': 7,
#   'नीधि': 3,
#   'जनजाती': 7,
#   'गोपालमान': 8,
#   'श्रेष्ठ': 269,
#   'हार्दिक': 1081,
#   'बधाई': 1007,
#   'समावेशी': 22,
#   'छडिएको': 1,
#   'हल्लो': 6,
#   'सरकार': 735,
#   'चोलेन्द्र': 4,
#   'कतार': 10,
#   'पठाएर': 14,
#   'परमादेश': 9,
#   'ब्राजिललाई': 1,
#   'जिताउन': 220,
#   'नगाए': 2,
#   'भ्रष्टाचार': 173,
#   'नियन्त्रण': 46,
#   'प्रतिबद्धता': 117,
#   'सक्रियता': 14,
#   'आवश्यक': 212,
#   'तपाइँ': 24,
#   'ठिक': 203,
#   'बाजे': 35,
#   'कुरामा': 85,
#   'ओलि': 248,
#   'गुणा': 35,
#   'रहेछन': 76,
#   'सिको': 6,
#   'महिलाबाट': 2,
#   'प्रतिनिधि': 557,
#   'सभामा': 154,
#   'पर्न': 51,
#   'सफल': 652,
#   'महिला': 544,
#   'पिछडिएका': 5,
#   'महिलाको': 65,
#   'तर्फबाट': 365,
#   'श्रीमति': 6,
#   'छनोट': 58,
#   'जोई': 1,
#   'देर': 12,
#   'बहादुर': 341,
#   'नपच्ने': 2,
#   'तपाइँलाई': 3,
#   'अपृय': 2,
#   'लाग्छ': 400,
#   'मेरा': 101,
#   'जनादेश': 12,
#   'ताण्डव': 3,
#   'म्याडम': 13,
#   'गठवन्धनको': 19,
#   'देखिएकै': 3,
#   'ओलिलाई': 16,
#   'फ्लप': 11,
#   'खुलाउने': 8,
#   'विश्वकप': 14,
#   'जितिसकेको': 2,
#   'ब्राजिलले': 2,
#   'छैठौंपल्ट': 1,
#   'जित्नुपर्छ': 30,
#   'भन्नु': 185,
#   'भइसकेका': 21,
#   'हुनुपर्छ': 213,
#   'आवश्यकः': 3,
#   'उहाँले': 83,
#   'योगदानलाई': 7,
#   'सम्मान': 186,
#   'चलाउन': 60,
#   'सक्नुहुन्न': 5,
#   'युवा': 512,
#   'विकासमा': 38,
#   'त्रिविको': 8,
#   'योगदान': 132,
#   'अतुलनिय': 3,
#   'देशको': 490,
#   'कायापलट': 12,
#   'हुनलाई': 14,
#   'बन्नुपर्छ': 23,
#   'ढुक्क': 104,
#   'अर्जेन्टिना': 8,
#   'जित्नपर्छ': 3,
#   'त्रिभुवन': 12,
#   'विश्वविद्यालयले': 3,
#   'नेपालको': 471,
#   'शिर': 25,
#   'उच्च': 92,
#   'बनाएको': 129,
#   'शिक्षाको': 22,
#   'महत्त्वपूर्ण': 50,
#   'क्षेत्रबाट': 66,
#   'सदस्य': 1252,
#   'शुभकामना': 1217,
#   'गर्दछु': 400,
#   'शैक्षिक': 33,
#   'महत्वपूर्ण': 98,
#   'विश्वविद्यालयको': 6,
#   'नाे': 3,
#   'नट': 14,
#   'अगेन': 6,
#   'काे': 295,
#   'तिनै': 61,
#   'नेतालाई': 121,
#   'जिताउ': 53,
#   'बुझेछन्': 7,
#   'जनताले': 667,
#   'नानिका': 8,
#   'अाउनु': 4,
#   'भाे': 33,
#   'बुद्धि': 54,
#   'फुल्नु': 2,
#   'उस्ता': 4,
#   'बुझाइ': 18,
#   'गद्दारी': 7,
#   'गर्दैनौँ': 2,
#   'बेइमानी': 7,
#   'जनताको': 677,
#   'सपना': 147,
#   'मर्न': 15,
#   'दिँदैनौँ': 2,
#   'बचाउनु': 10,
#   'जनता': 896,
#   'मलामी': 10,
#   'कमाउनु': 2,
#   'दीपकबहादुर': 3,
#   'सिंह': 329,
#   'राप्रपा': 1003,
#   'नवनिर्वाचित': 47,
#   'सांसद्': 5,
#   'मान्छे': 551,
#   'संसदमा': 100,
#   'उभिएर': 11,
#   'बोलेको': 43,
#   'सुन्न': 80,
#   'आतुर': 19,
#   'दाेलखा': 2,
#   'काठमाडौं': 1013,
#   'सम्पर्क': 53,
#   'समाजकाे': 1,
#   'आयाेजनामा': 2,
#   'राप्रपाका': 127,
#   'माननियहरू': 2,
#   'वरिष्ठ': 93,
#   'दिपक': 78,
#   'विक्रम': 36,
#   'पाण्डे': 79,
#   'प्रधान': 68,
#   'सिँह': 6,
#   'उद्धव': 7,
#   'राजु': 63,
#   'विष्टलाई': 9,
#   'वधाई': 25,
#   'दिईयाे': 1,
#   'याे': 150,
#   'जारी': 315,
#   'रहनेछ': 26,
#   'नेतृत्वको': 139,
#   'अनुहार': 93,
#   'बदलिदा': 2,
#   'कती': 45,
#   'कमल': 184,
#   'छदाँ': 2,
#   'कटाउन': 8,
#   'नसकेको': 48,
#   'राप्रपाले': 84,
#   'राजेन्द्र': 156,
#   'लिङ्देन': 71,
#   'नेतृत्वमा': 105,
#   'ल्याउदा': 11,
#   'रास्टृय': 5,
#   'पार्टी': 1937,
#   'बन्यो': 71,
#   'मत': 2733,
#   'सांसद': 189,
#   'पाचौ': 5,
#   'शक्ती': 20,
#   'बन्ने': 259,
#   'यसबाट': 16,
#   'अरुले': 49,
#   'सागर': 200,
#   'ढकाल': 108,
#   'बुझ्न': 107,
#   'क्षमतावान': 20,
#   'समाजलाई': 12,
#   'वास्तविकता': 15,
#   'बुझाएर': 18,
#   'बढ्ने': 48,
#   'किन्तु': 2,
#   'परन्तु': 3,
#   'नभनि': 7,
#   'राजनिती': 126,
#   'गर्नुहोस्': 88,
#   'रबि': 69,
#   'छिन': 21,
#   'आइपुन्नेछन्': 1,
#   'लोकतन्त्रले': 2,
#   'लोकको': 2,
#   'बिश्वास': 63,
#   'जित्न': 260,
#   'सकेन': 46,
#   'लोकतन्त्रका': 18,
#   'दलहरु': 57,
#   'अराजक': 33,
#   'बिश्वासलाई': 2,
#   'रा': 66,
#   'स्व': 52,
#   'उन्मुक्ति': 22,
#   'जनमत': 145,
#   'पार्टि': 129,
#   'स्वतन्त्र': 1631,
#   'व्यक्तिहरुलाई': 2,
#   'बिस्तारै': 37,
#   'सारेका': 12,
#   'सारे': 6,
#   'आवाज': 81,
#   'आएन': 38,
#   'निर्बाचनमा': 21,
#   'जोर': 3,
#   'सार्छन': 1,
#   'होर': 27,
#   'तेहि': 62,
#   'माकुने': 141,
#   'बहुमत': 196,
#   'जित्नु': 147,
#   'गणतन्त्र': 288,
#   'नायक': 34,
#   'अपाङ्गता': 20,
#   'अधिकारकर्मीहरु': 1,
#   'मित्रहरु': 12,
#   'भोजराज': 8,
#   'काग्रेस': 104,
#   'लक्ष्मी': 24,
#   'घिमिरे': 59,
#   'बागमती': 89,
#   'सदस्यमा': 331,
#   'मनोनित': 6,
#   'हुनुभएकोमा': 138,
#   'कार्यकाल': 98,
#   'सफलताको': 52,
#   'दलले': 159,
#   'ब्याक्तीलाई': 2,
#   'कमजोर': 94,
#   'नसोचौ': 2,
#   'पार्टीको': 537,
#   'नेतृत्व': 369,
#   'सहि': 290,
#   'भैदियो': 2,
#   'जनतामा': 57,
#   'छाप': 267,
#   'छोड्न': 17,
#   'राष्ट्रिय': 671,
#   'प्रजातन्त्र': 137,
#   'प्रमाणित': 67,
#   'गरिदिएको': 5,
#   'अघिल्लो': 126,
#   'निर्वाचनमा': 1001,
#   'प्रदेशतर्फ': 3,
#   'प्रतिनिधिसभामा': 55,
#   'जम्मा': 177,
#   'सिट': 218,
#   'जितेको': 265,
#   'प्रदेशसभामा': 35,
#   'नजान्ने': 11,
#   'मान्छेको': 36,
#   'बिचार': 173,
#   'ठाउमा': 105,
#   'भयको': 54,
#   'एकमात्र': 28,
#   'बिचारले': 7,
#   'स्पस्ट': 6,
#   'सिद्दान्तमा': 2,
#   'अडिग': 11,
#   'पाटी': 82,
#   'राम्रा': 112,
#   'आउनुपर्छ': 13,
#   'राप्रपामा': 21,
#   'होलि': 5,
#   'वाइन': 7,
#   'बाउको': 19,
#   'नगर्ने': 118,
#   'माधौ': 5,
#   'छोडेर': 101,
#   'आउनुस': 24,
#   'संख्या': 118,
#   'गण्डकी': 70,
#   'जनमोर्चा': 25,
#   'प्रवेश': 480,
#   'गठनको': 5,
#   'सम्भावित': 26,
#   'चुनाववाट': 3,
#   'सव': 3,
#   'खुशी': 121,
#   'देखिन्छन्': 16,
#   'कांग्रेसले': 554,
#   'प्रत्यक्षमा': 37,
#   'मख्ख': 10,
#   'माओवादी': 1727,
#   'नसक्ने': 151,
#   'नेकपा': 2313,
#   'महिनामा': 31,
#   'बढेको': 81,
#   'हिस्स': 3,
#   'थापाले': 136,
#   'छाडेपछि': 2,
#   'ओलीलाई': 67,
#   'आफुले': 86,
#   'सुध्रिन्छ': 3,
#   'छाड्दैनन्': 1,
#   'ठोके': 7,
#   'लाग्यो': 280,
#   'रबिन्द्र': 62,
#   'मपाई': 1,
#   'अवार्ड': 10,
#   'बर्ष': 355,
#   'पशुपतिनाथ': 32,
#   'कल्याण': 20,
#   'गरून': 5,
#   'सिटे': 3,
#   'पुर्याएर': 12,
#   'पाँचौँ': 15,
#   'शक्ति': 239,
#   'बन्नुको': 1,
#   'सम्पूर्ण': 326,
#   'श्रेय': 9,
#   'अध्यक्ष': 1707,
#   'लिङ्देनलाई': 3,
#   'जिकिर': 9,
#   'चुनाव': 2107,
#   'आवधिक': 28,
#   'कामको': 54,
#   'आधारमा': 191,
#   'जित': 542,
#   'हार': 198,
#   'चुनावमा': 664,
#   'राम्राले': 3,
#   'जित्छन्': 33,
#   'उम्मेदवारको': 317,
#   'छवी': 3,
#   'मतदाताहरूको': 3,
#   'विवेक': 78,
#   'परिस्थितीमा': 4,
#   'यसपाली': 154,
#   'अवश्य': 56,
#   'ठाउँ': 163,
#   'राम्रै': 123,
#   'टक्कर': 44,
#   'दिनेछन्': 9,
#   'संगठन': 95,
#   'हातमा': 139,
#   'भएनन्': 15,
#   'सखाफ': 1,
#   'पारेर': 43,
#   'मिश्र': 101,
#   'गएपछि': 21,
#   'छोटो': 18,
#   'सकेनन': 23,
#   'गरेनन': 7,
#   'देशभरि': 19,
#   'लहर': 48,
#   'घन्टी': 35,
#   'बज्यो': 7,
#   'मिलन': 18,
#   'बाढी': 8,
#   'थेग्न': 5,
#   'भूमिका': 74,
#   'दोष': 42,
#   'मिश्रको': 32,
#   'कांग्रेस': 2697,
#   'डर': 64,
#   'पन्च': 4,
#   'संगको': 18,
#   'मिलेर': 242,
#   'जोगाउने': 43,
#   'भन्नेमा': 41,
#   'जाउ': 38,
#   'रिसाउने': 4,
#   'नजाउ': 6,
#   'रहने': 104,
#   'जय': 1177,
#   'स्वतन्त्रहरू': 3,
#   'सरकारमा': 71,
#   'जानुपर्छ': 11,
#   'भ्रष्टाचारीको': 2,
#   'पार्टीका': 351,
#   'सभापति': 921,
#   'पदाधिकारी': 27,
#   'मनोनयन': 272,
#   'आशिर्वादले': 3,
#   'भातृ': 10,
#   'बनाई': 34,
#   'कोल्याप्स': 3,
#   'निर्वाचन': 7252,
#   'कार्यालय': 189,
#   'चरिकोटमा': 2,
#   'गरेपछि': 97,
#   'भनाई': 53,
#   'पूरा': 232,
#   'जिम्मेवारी': 115,
#   'निर्वाचित': 1325,
#   'भरत': 23,
#   'केसी': 88,
#   'कार्यकालको': 274,
#   'रेक्टर': 1,
#   'प्रा': 25,
#   'शर्मा': 324,
#   'सरले': 29,
#   'पत्र': 218,
#   'लेखिदिनु': 1,
#   'जापान': 21,
#   'पठाएँ': 2,
#   'अन्तर्राष्ट्रिय': 109,
#   'सम्मेलनमा': 14,
#   'भाग': 109,
#   'लिदा': 7,
#   'खर्च': 272,
#   'आयोजकले': 2,
#   'ब्यहोर्ने': 1,
#   'व्यवस्था': 310,
#   'पासपोर्ट': 30,
#   'खर्चको': 28,
#   'अनुरोध': 267,
#   'मिल्दैन': 68,
#   'लघुवित्तको': 2,
#   'अध्यक्षमा': 577,
#   'केशव': 318,
#   'राज': 58,
#   'टुक्का': 12,
#   'आन्दोलन': 59,
#   'युद्ध': 21,
#   'शुरु': 102,
#   'दल': 962,
#   'मित्र': 79,
#   'पढ्न': 45,
#   'पाएँ': 8,
#   'समानुपातिकतर्फको': 16,
#   'चयन': 77,
#   'टुंगाे': 2,
#   'लगाउँदै': 12,
#   'केन्द्र': 522,
#   'नेपाली': 7083,
#   'एकीकृत': 414,
#   'समाजवादी': 413,
#   'समाजवादीको': 56,
#   'नेकां': 3,
#   'एमालेको': 663,
#   'प्रतिपक्षी': 28,
#   'बनेर': 102,
#   'बस्नुपर्छ': 7,
#   'माओवादीले': 135,
#   'कत्ती': 9,
#   'सत्ताको': 41,
#   'चाख्ने': 1,
#   'कामरेडहरु': 4,
#   'गठनका': 6,
#   'विकल्प': 150,
#   'खुला': 49,
#   'निर्णय': 363,
#   'एमालेसँग': 30,
#   'सहकार्य': 59,
#   'सच्चिएर': 1,
#   'संसद्मा': 13,
#   'संघीयताको': 4,
#   'पक्षधर': 28,
#   'समाजवादीले': 36,
#   'खारेजीको': 14,
#   'जनमोर्चाका': 15,
#   'चित्रबहादुर': 12,
#   'केसीलाई': 5,
#   'जिताएर': 47,
#   'माननीय': 50,
#   'बनाएका': 84,
#   'पुरुष': 65,
#   'पाउने': 309,
#   'भएकाले': 84,
#   'केन्द्रमा': 269,
#   'आकांक्षी': 8,
#   'नेताहरू': 65,
#   'सकसमा': 1,
#   'पठाउँदा': 7,
#   'खस': 9,
#   'आर्यको': 1,
#   'नम्बरमा': 35,
#   'हितराज': 2,
#   'पाण्डेले': 32,
#   'अवसर': 147,
#   'सम्भावना': 164,
#   'बलियो': 212,
#   'केन्द्रको': 98,
#   'आन्दोलनको': 17,
#   'एजेण्डाको': 3,
#   'अन्तिम': 302,
#   'स्वास': 2,
#   'रहुन्जेल': 11,
#   'गाउका': 2,
#   'मान्छेले': 81,
#   'जान्नु': 8,
#   'जानेका': 13,
#   'अन्न': 10,
#   'फलाउन': 3,
#   'स्वाभिमान': 36,
#   'श्रम': 47,
#   'गफको': 2,
#   'खेति': 13,
#   'दास': 57,
#   'निकट': 50,
#   'विद्यार्थी': 36,
#   'अनेरास्ववियू': 2,
#   'क्रान्तिकारी': 54,
#   'होनहार': 11,
#   'कमरेडहरु': 9,
#   'सुखद': 39,
#   'दाम्पत्य': 2,
#   'नेताहरूबीच': 3,
#   'विषयमा': 138,
#   'विमति': 3,
#   'शिखण्डी': 1,
#   'कोरल्ने': 2,
#   'ह्याचरी': 3,
#   'अनवरत': 7,
#   'साझेदारी': 7,
#   'उद्योगको': 4,
#   'प्रबन्धपत्र': 2,
#   'लेखनको': 2,
#   'अग्रसरता': 5,
#   'सधैंजसो': 1,
#   'पुष्पकमल': 117,
#   'दाहालले': 70,
#   'लिँदैआएका': 2,
#   'देउवाको': 171,
#   'हिस्सेदारी': 2,
#   'कहिल्यै': 82,
#   'दोलखाबाट': 3,
#   'केन्द्रका': 291,
#   'गंगा': 36,
#   'कार्की': 111,
#   'श्रदय': 3,
#   'दाहाल': 252,
#   'भेटघाट': 57,
#   'खुमलटार': 4,
#   'ललितपुर': 202,
#   'मुक्तिगामी': 2,
#   'जनतासँग': 16,
#   'संघर्षको': 9,
#   'मैदानमा': 123,
#   'गरिने': 84,
#   'एकता': 102,
#   'मतिभ्रष्ट': 2,
#   'नेताहरूकाे': 4,
#   'सेतै': 2,
#   'फुलेको': 3,
#   'कपाल': 8,
#   'परेकाे': 10,
#   'उनीहरू': 20,
#   'ओथाराे': 2,
#   'कार्यालयमा': 77,
#   'खादा': 16,
#   'हुनसक्दैन': 5,
#   'लडाइँ': 20,
#   'खुराफाती': 1,
#   'लडाकु': 3,
#   'प्रलोभनमा': 16,
#   'फसेका': 7,
#   'हैनन्': 32,
#   'मैदान': 16,
#   'पतीत': 1,
#   'निर्णायक': 53,
#   'गठबन्धनमा': 85,
#   'जोडे': 3,
#   'बन्छ': 105,
#   'देउबा': 43,
#   'गुरिल्ला': 4,
#   'मुक्त': 87,
#   'राजनीतिक': 588,
#   'यात्रा': 95,
#   'शुरुवात': 15,
#   'पुस्ताको': 34,
#   'कार्यक्रमका': 22,
#   'गठबन्धन': 1598,
#   'रास्वपा': 31,
#   'जसपा': 178,
#   'शसक्त': 9,
#   'रचनात्मक': 5,
#   'प्रतिपक्षको': 8,
#   'भुमिकामा': 8,
#   'पुनः': 137,
#   'युवाहरु': 42,
#   'छलफलमा': 16,
#   'जुटेछन': 1,
#   'मनमा': 72,
#   'मुल': 37,
#   'नेताको': 125,
#   'निर्धक्क': 52,
#   'राख्न': 128,
#   'सकिन्न': 51,
#   'देखावटी': 3,
#   'चहलपहलले': 2,
#   'उहीँ': 24,
#   'नेतृत्वलाई': 25,
#   'आकर्षित': 11,
#   'कम्तिमा': 54,
#   'राप्रपाबाट': 26,
#   'सिक्नु': 15,
#   'एकमा': 36,
#   'संभावना': 39,
#   'स्वार्थ': 65,
#   'छान': 2,
#   'थोरै': 60,
#   'सुशासन': 76,
#   'बढोस्': 2,
#   'प्रजातन्त्रको': 21,
#   'स्थिरता': 30,
#   'रहोस्': 37,
#   'लगायतले': 5,
#   'च्याखे': 2,
#   'थाप्न': 5,
#   'नपाउन्': 2,
#   'भावनाले': 4,
#   'चाह': 4,
#   'स्थीर': 3,
#   'बनाइयोस्': 2,
#   'बल्ल': 123,
#   'धन्यवाद': 299,
#   'स्विकरिन्छ': 1,
#   'पल्टै': 2,
#   'खेल': 86,
#   'पत्ता': 46,
#   'साफ': 34,
#   'गरिन्छ': 60,
#   'अहिलेको': 157,
#   'मुख्यमन्त्री': 79,
#   'साइत': 12,
#   'साईबर': 1,
#   'सेना': 60,
#   'अली': 21,
#   'रिमाल': 10,
#   'भाईको': 14,
#   'हात': 183,
#   'धोएर': 3,
#   'रमाईलो': 16,
#   'कौनसा': 2,
#   'ठुलो': 179,
#   'नौलो': 20,
#   'कुरो': 289,
#   'बिश्व': 27,
#   'बजारमा': 81,
#   'कच्चा': 4,
#   'पदार्थ': 12,
#   'आयात': 27,
#   'झेल्नु': 1,
#   'समस्या': 195,
#   'नेपालमै': 20,
#   'बनाइएका': 12,
#   'बस्तु': 15,
#   'उत्पादन': 54,
#   'सस्तो': 25,
#   'उपयोग': 31,
#   'गर्छन': 115,
#   'बजार': 53,
#   'बिर्सेर': 17,
#   'घरेलु': 14,
#   'प्रयोग': 449,
#   'भन्लान': 6,
#   'नेकाले': 5,
#   'विरुद्द': 6,
#   'पठाएको': 22,
#   'दलको': 295,
#   'गठवन्धन': 43,
#   'प्रत्यक्ष': 174,
#   'सॅासद': 2,
#   'बढाएको': 13,
#   'अनुपातमा': 5,
#   'ल्याएको': 109,
#   'पार्टीसॅग': 2,
#   'बिदेशी': 41,
#   'नामधारी': 3,
#   'नेताका': 42,
#   'नामका': 11,
#   'रहँदासम्म': 2,
#   'सुकुम्वासी': 6,
#   'महासचिव': 97,
#   'नेत्रविक्रम': 11,
#   'चन्दले': 4,
#   'मंसिर': 791,
#   'गतेको': 69,
#   'निर्वाचनले': 35,
#   'रुपान्तरण': 21,
#   'परिवर्तन': 400,
#   'पारेको': 49,
#   'अख्तियार': 17,
#   'प्रमुख': 876,
#   'नियुक्त': 92,
#   'ब्यवस्था': 44,
#   'चाहिने': 56,
#   'दिऔं': 17,
#   'पार्छ': 18,
#   'हालतमा': 35,
#   'मान्दैनन': 5,
#   'उपाध्यक्ष': 252,
#   'विष्णुप्रसाद': 6,
#   'पौडेलले': 148,
#   'सशक्त': 31,
#   'निर्वाह': 22,
#   'बुटवलमा': 49,
#   'पत्रकारसँग': 3,
#   'धारणा': 50,
#   'वाम': 43,
#   'एकताको': 19,
#   'छोड्नुहोस्': 2,
#   'एमालेलाई': 236,
#   'सोसल': 17,
#   'डेमोक्रेटिक': 2,
#   'रूपमा': 247,
#   'विकास': 453,
#   'लाग्नु': 63,
#   'हँसिया': 81,
#   'हथौडा': 55,
#   'हटाउनु': 4,
#   'पार्टीमा': 125,
#   'महाधिवेशनमा': 20,
#   'काँग्रेसको': 129,
#   'गलत': 212,
#   'नीति': 128,
#   'कम्युनिस्ट': 152,
#   'वलियो': 4,
#   'वने': 2,
#   'बाम': 77,
#   'दाहिने': 8,
#   'बुझिन्छ': 12,
#   'सत्तापक्ष': 4,
#   'प्रतिपक्ष': 26,
#   'कम्युनिष्टको': 12,
#   'हातले': 15,
#   'सामान': 23,
#   'खाना': 44,
#   'पूजा': 14,
#   'मानिदैन': 1,
#   'बेथिति': 17,
#   'हेर्दा': 232,
#   'राजसंस्था': 26,
#   'स्थायित्वको': 6,
#   'अपरिहार्य': 11,
#   'रहन्छ': 64,
#   'देशमा': 245,
#   'पुनःस्थापनाका': 1,
#   'घटकले': 1,
#   'संघियता': 48,
#   'हारको': 26,
#   'जिम्मा': 124,
#   'कार्ल': 3,
#   'मार्क्स': 8,
#   'लेनिन': 4,
#   'स्टालिन': 1,
#   'दिदै': 45,
#   'समाजवाद': 50,
#   'पर्नु': 27,
#   'सम्पुर्ण': 217,
#   'जनतालाई': 217,
#   'विसर्जन': 3,
#   'बढ्न': 27,
#   'विनय': 1,
#   'याचना': 2,
#   'योजनाबद्ध': 7,
#   'रूपमै': 5,
#   'कार्यकर्ता': 345,
#   'आफूमा': 2,
#   'विलय': 4,
#   'गराएर': 49,
#   'शक्तिशाली': 40,
#   'एमालेले': 549,
#   'साना': 39,
#   'पार्टीहरूको': 5,
#   'गाभेको': 2,
#   'साँचाे': 2,
#   'सलाम': 89,
#   'आफ्नाे': 29,
#   'जिन्दगी': 34,
#   'राष्ट्रकाे': 2,
#   'भविष्य': 102,
#   'दाइ': 226,
#   'काङ्ग्रेस': 730,
#   'कमरेड': 618,
#   'नाममा': 137,
#   'उत्तानो': 12,
#   'पार्ने': 75,
#   'प्रचलन': 9,
#   'अन्त': 71,
#   'आशा': 155,
#   'पिछलग्गु': 2,
#   'तिम्राे': 2,
#   'कानमा': 3,
#   'घण्टी': 99,
#   'जाग': 8,
#   'सिद्धान्त': 81,
#   'बुझेर': 36,
#   'राजनीतिमा': 204,
#   'पक्ष': 93,
#   'विपक्ष': 8,
#   'कम्युनिष्टकै': 2,
#   'चल्न': 21,
#   'बनाउनु': 105,
#   'धार': 32,
#   'चरित्र': 41,
#   'बुझिने': 5,
#   'बनेको': 196,
#   'आयोगका': 110,
#   'प्रतिनिधिसभा': 1086,
#   'पर्सा': 21,
#   'उम्मेदवार': 3000,
#   'राजकुमार': 34,
#   'गुप्ता': 14,
#   'ल्याई': 43,
#   'विजयी': 2893,
#   'शुभकामनाएं': 3,
#   'प्रत्यक्षतर्फको': 9,
#   'क्षेत्रको': 87,
#   'मतगणना': 580,
#   'सकिएको': 47,
#   'सूर्यलाई': 13,
#   'छेक्दै': 1,
#   'सबैभन्दा': 302,
#   'जित्ने': 463,
#   'कम्युनिष्टहरूको': 1,
#   'मोर्चा': 16,
#   'शक्तिको': 43,
#   'तत्कालै': 7,
#   'अहिलेलाई': 14,
#   'संविधान': 135,
#   'लोकतन्त्रलाई': 20,
#   'सुदृढ': 25,
#   'बनाउनका': 5,
#   'वर्तमान': 58,
#   'गठबन्धनलाई': 261,
#   'निरन्तरता': 35,
#   'एकमत': 3,
#   'असल': 165,
#   'मानिस': 62,
#   'नजरमा': 19,
#   'झोला': 26,
#   'नबोकी': 2,
#   'काममा': 50,
#   'समर्थन': 295,
#   'खराब': 44,
#   'खबरदारी': 25,
#   'हुन्नन्': 2,
#   'बन्दैन': 22,
#   'नागरिक': 246,
#   'सहिलाई': 3,
#   'गलतलाई': 7,
#   'अन्धो': 9,
#   'झोले': 80,
#   'सद्दे': 2,
#   'असली': 42,
#   'मनाङे': 13,
#   'गर्नुभएछ': 3,
#   'हातबाट': 6,
#   'माला': 46,
#   'गर्दैगर्दा': 4,
#   'आन्दोलनले': 3,
#   'गति': 38,
#   'लिन्छ': 13,
#   'साँच्चिकै': 14,
#   'आउँछ': 159,
#   'हाम्लाई': 32,
#   'लाइराछ': 7,
#   'आत्मरति': 3,
#   'यथार्थ': 36,
#   'बुझ्नु': 57,
#   'ब्राजिल': 4,
#   'क्रोएसिया': 2,
#   'कोमल': 23,
#   'भनेपछि': 66,
#   'जिन्दावाद': 198,
#   'प्रचारमा': 65,
#   'भान': 7,
#   'शहरमा': 28,
#   'गाउँ': 279,
#   'गाउँमा': 89,
#   'बरिस्ठ': 13,
#   'उम्मेदवारलाई': 342,
#   'केन्दिय': 2,
#   'प्रचारले': 1,
#   'सहयोग': 295,
#   'गरेन': 43,
#   'सामाग्री': 25,
#   'बनाएन': 3,
#   'यस्तोमा': 7,
#   'पिएम': 7,
#   'राप': 9,
#   'सुहाउँछ': 9,
#   'भर्खरको': 1,
#   'ताण्डब': 2,
#   'पुगेन': 24,
#   'अलोकतान्त्रिक': 9,
#   'हर्कत': 14,
#   'राष्ट्रपति': 112,
#   'उत्तम': 47,
#   'निकास': 31,
#   'लेखेको': 46,
#   'ठोक्दैछन्': 1,
#   'भाषा': 107,
#   'रमाएका': 3,
#   'शम्शेर': 5,
#   'आम': 221,
#   'कानून': 33,
#   'गरियो': 118,
#   'विवादमा': 10,
#   'आउनेछैन': 1,
#   'लोकेन्द्र': 6,
#   'प्रचण्डले': 131,
#   'कमजोरछैन': 1,
#   'फरकछन्': 1,
#   'छुट्टै': 30,
#   'उद्योग': 71,
#   'सफलता': 82,
#   'ठान्छन्': 4,
#   'मुख': 65,
#   'हेर्दिन': 1,
#   'दिन्न': 31,
#   'देउवामा': 2,
#   'समानता': 24,
#   'आग्रह': 278,
#   'पर्दैन्': 6,
#   'घुमिफिरि': 1,
#   'विदेशी': 62,
#   'दलालहरूकै': 1,
#   'रामचन्द्र': 134,
#   ...}}

# %%
vocab_class.keys()
# Out:
# dict_keys([1, 0])

# %% [markdown]
# ### Most Repeated Words in Each Labels

# %%
vocab_class[1] = dict(sorted(vocab_class[1].items(), key=lambda x:x[1], reverse=True))
vocab_class[0] = dict(sorted(vocab_class[0].items(), key=lambda x:x[1], reverse=True))

# %%
data = [list(vocab_class[1].keys()), [1]*len(vocab_class[1]), list(vocab_class[1].values())]

vocab_class_df = pd.DataFrame(columns=['word', 'label', 'count'])
vocab_class_df['word']=list(vocab_class[1].keys())+list(vocab_class[0].keys())
vocab_class_df['label']=[1]*len(vocab_class[1])+[0]*len(vocab_class[0])
vocab_class_df['count']=list(vocab_class[1].values())+list(vocab_class[0].values())


vocab_class_df
# Out:
#             word  label  count
# 0            भोट      1  10904
# 1       निर्वाचन      1   5221
# 2         नेपाली      1   5134
# 3          देउवा      1   4109
# 4           मेयर      1   2686
# ...          ...    ...    ...
# 89197  पौड्यालले      0      1
# 89198   जाेगाउने      0      1
# 89199   जुत्ताको      0      1
# 89200     मालाले      0      1
# 89201    तीनिहरु      0      1
#
# [89202 rows x 3 columns]

# %%
vocab_class_df.query("label==1").iloc[:10]
# Out:
#          word  label  count
# 0         भोट      1  10904
# 1    निर्वाचन      1   5221
# 2      नेपाली      1   5134
# 3       देउवा      1   4109
# 4        मेयर      1   2686
# 5       चुनाव      1   2630
# 6  उम्मेदवारी      1   2488
# 7    कांग्रेस      1   2482
# 8      पार्टी      1   2355
# 9     माओवादी      1   2032

# %%
clean_text = []
text_label = []
found_word = []
# 1, 0: pos, neg

for label in [0,1]:
  words= vocab_class_df.query("label==@label").iloc[:1].word.tolist()
  for word in words:
    for i, row in filtered_data.query('label==@label').iterrows():
      if word in row.clean_tokenized_text:
        clean_text.append(row.clean_tokenized_text)
        found_word.append(word)
        text_label.append(label)
        break

  words= vocab_class_df.query("label==@label").iloc[-100:-98].word.tolist()
  for word in words:
    for i, row in filtered_data.query('label==@label').iterrows():
      if word in row.clean_tokenized_text:
        clean_text.append(row.clean_tokenized_text)
        found_word.append(word)
        text_label.append(label)
        break

vcdf = pd.DataFrame(columns=['clean_text', 'text_label', 'found_word'])
vcdf['clean_text'] = clean_text
vcdf['text_label'] = text_label
vcdf['found_word'] = found_word

vcdf
# Out:
#                                           clean_text  text_label found_word
# 0  मतदाताले कांग्रेसलाई भोट युवाको हातमा पार्टी ज...           0        भोट
# 1  गज्जब भएछ नेपालको न्यायलयले साधारण नेपाली संबै...           0    जिताउन्
# 2  गाउँ राजनितिमा बर्शे ठिटो बर्षको गवार बर्षका व...           0       ठिटो
# 3  भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्...           1        भोट
# 4  जबसम्म ह्याङ्ग दाईले जम्मा पारेर दाई रुदै भिडी...           1   फिल्मलाई
# 5         विश्वप्रकाश गठबन्धन ताेला सुन क्वीन्टल आलु           1      ताेला

# %%
vcdf.to_csv('vcdf.csv')

# %% [markdown]
# # Using TFiDF

# %%
filtered_data
# Out:
#        Unnamed: 0                   id  \
# 63512        6550  1519923310947373056
# 59575        1950  1522612435114287104
# 29674         733  1526560690055500032
# 15413        1520  1588871568620675072
# 57544        8443  1522955026104160000
# ...           ...                  ...
# 72913        8820  1519346755158298880
# 72959        8886  1519237744316329984
# 72967        8897  1520662751265260032
# 72968        8898  1520662742067080960
# 72969        8899  1520662453193175040
#
#                                                     text  label Unnamed: 3  \
# 63512  सत्तारुढ गठबन्धनले पाँच दलीय गठबन्धन बाहिरका द...      1        NaN
# 59575  भोट के मा फलानो चिन्हमा भन्ने मात्रै सुनियो तर...      1        NaN
# 29674  @realpbhattarai १४ हाम्रो यो कलंकी area को आशै...      1        NaN
# 15413  @kandeldai हैट कम्युनिस्ट भएर राप्रपा लाइ भोट ...      1        NaN
# 57544  भोट माग्न आउँदा ५ वर्षलाई कमसेकम ५ लाख जति लिए...      1        NaN
# ...                                                  ...    ...        ...
# 72913  दशकौंदेखि नेका.का.क्षेत्र ३को अभिभावक रहेको अम...      0        NaN
# 72959  पार्टीले टिकट दिएन भनेर पार्टीबाट राजीनामा दिन...      0        NaN
# 72967  किसानो के ढ्वार योगी सरकार https://t.co/83zyxZ...      0        NaN
# 72968  @KiranjainReal #हर____हर___महादेव 🙏🚩🚩\nजय श्री...      0        NaN
# 72969  तालमेल नभएका ठाउँमा पनि मिलेन चुनाव लड्न सत्ता...      0        NaN
#
#                                     clean_tokenized_text
# 63512  सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग ...
# 59575  भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्...
# 29674  कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ...
# 15413  कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कां...
# 57544          भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान
# ...                                                  ...
# 72913  अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजि...
# 72959  टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी त...
# 72967                                         योगी सरकार
# 72968                                    जय महाकाल सरकार
# 72969            तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको
#
# [91209 rows x 6 columns]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer

# Create TF-IDF Vectorizer
tfidf_vectorizer = TfidfVectorizer(tokenizer=lambda x: x.split(" "),
                                         sublinear_tf=True, encoding='utf-8',
                                         decode_error='ignore',
                                         stop_words=stop_words,
                                   vocabulary=vocab.keys()
                                   )


# get tfidf of all data
X_tfidf = tfidf_vectorizer.fit_transform(filtered_data['clean_tokenized_text'])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:409: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['भएप', 'ी', 'ु'] not in stop_words.
#   warnings.warn(

# %%
X_train_tfidf, X_test_tfidf, Y_train, Y_test = train_test_split(X_tfidf,
                                                        filtered_data['label'],
                                                        random_state=111, train_size=0.8)
X_train_tfidf.shape
# Out:
# (72967, 48832)

# %%
# now do split
# X_train_tfidf, X_test_tfidf, Y_train, Y_test = train_test_split(X_tfidf,
#                                                         filtered_data['label'],
#                                                         random_state=111, train_size=0.8)
# X_tfidf = tfidf_vectorizer.fit_transform(train_rows['clean_tokenized_text'])
# X_train_tfidf, X_test_tfidf = X_tfidf, tfidf_vectorizer.transform(test_rows['clean_tokenized_text'])
# Y_train, Y_test = train_rows['label'], test_rows['label']

# %%
X_test_tfidf.shape
# Out:
# (18242, 48832)

# %% [markdown]
# ## TFIDF Features

# %%
feature_names = tfidf_vectorizer.get_feature_names_out()
feature_names[0]
# Out:
# 'शाहहरुको'

# %%
tfidf_df = pd.DataFrame(X_tfidf.toarray(), index=filtered_data['clean_tokenized_text'], columns=feature_names)
tfidf_df
# Out:
#                                                     शाहहरुको  दगुरेको  \
# clean_tokenized_text
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...       0.0      0.0
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...       0.0      0.0
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...       0.0      0.0
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...       0.0      0.0
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान                0.0      0.0
# ...                                                      ...      ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...       0.0      0.0
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...       0.0      0.0
# योगी सरकार                                               0.0      0.0
# जय महाकाल सरकार                                          0.0      0.0
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको                  0.0      0.0
#
#                                                     कुम्भकरण  बताइदिनु  \
# clean_tokenized_text
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...       0.0       0.0
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...       0.0       0.0
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...       0.0       0.0
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...       0.0       0.0
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान                0.0       0.0
# ...                                                      ...       ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...       0.0       0.0
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...       0.0       0.0
# योगी सरकार                                               0.0       0.0
# जय महाकाल सरकार                                          0.0       0.0
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको                  0.0       0.0
#
#                                                     लठैतहरुको  निसाफ  ताउलोमा  \
# clean_tokenized_text
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...        0.0    0.0      0.0
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...        0.0    0.0      0.0
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...        0.0    0.0      0.0
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...        0.0    0.0      0.0
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान                 0.0    0.0      0.0
# ...                                                       ...    ...      ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...        0.0    0.0      0.0
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...        0.0    0.0      0.0
# योगी सरकार                                                0.0    0.0      0.0
# जय महाकाल सरकार                                           0.0    0.0      0.0
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको                   0.0    0.0      0.0
#
#                                                     हाजिरि  तिनलाख  दाइजोका  \
# clean_tokenized_text
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...     0.0     0.0      0.0
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...     0.0     0.0      0.0
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...     0.0     0.0      0.0
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...     0.0     0.0      0.0
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान              0.0     0.0      0.0
# ...                                                    ...     ...      ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...     0.0     0.0      0.0
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...     0.0     0.0      0.0
# योगी सरकार                                             0.0     0.0      0.0
# जय महाकाल सरकार                                        0.0     0.0      0.0
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको                0.0     0.0      0.0
#
#                                                     ...     चुनाव  स्थानीय  \
# clean_tokenized_text                                ...
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...  ...  0.000000      0.0
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...  ...  0.000000      0.0
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...  ...  0.000000      0.0
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...  ...  0.000000      0.0
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान           ...  0.000000      0.0
# ...                                                 ...       ...      ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...  ...  0.000000      0.0
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...  ...  0.168535      0.0
# योगी सरकार                                          ...  0.000000      0.0
# जय महाकाल सरकार                                     ...  0.000000      0.0
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको             ...  0.248554      0.0
#
#                                                     उम्मेदवारी  उम्मेदवार  \
# clean_tokenized_text
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...         0.0        0.0
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...         0.0        0.0
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...         0.0        0.0
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...         0.0        0.0
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान                  0.0        0.0
# ...                                                        ...        ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...         0.0        0.0
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...         0.0        0.0
# योगी सरकार                                                 0.0        0.0
# जय महाकाल सरकार                                            0.0        0.0
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको                    0.0        0.0
#
#                                                     कांग्रेस  देउवा  मेयर  \
# clean_tokenized_text
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...  0.000000    0.0   0.0
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...  0.000000    0.0   0.0
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...  0.000000    0.0   0.0
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...  0.114274    0.0   0.0
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान           0.000000    0.0   0.0
# ...                                                      ...    ...   ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...  0.000000    0.0   0.0
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...  0.000000    0.0   0.0
# योगी सरकार                                          0.000000    0.0   0.0
# जय महाकाल सरकार                                     0.000000    0.0   0.0
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको             0.000000    0.0   0.0
#
#                                                     नेपाली  निर्वाचन       भोट
# clean_tokenized_text
# सत्तारुढ गठबन्धनले दलीय गठबन्धन बाहिरका दलसँग च...     0.0       0.0  0.000000
# भोट फलानो चिन्हमा सुनियो मतपत्र भोट जानकारि ज्य...     0.0       0.0  0.188576
# कलंकी आशै नगरे स्थापित बाले जमानामा उती भोट उफ्...     0.0       0.0  0.122589
# कम्युनिस्ट राप्रपा भोट माग्ने अधक्ष्य हुदै कांग...     0.0       0.0  0.185184
# भोट माग्न आउँदा वर्षलाई आउ तिहारमा नाचगान              0.0       0.0  0.135629
# ...                                                    ...       ...       ...
# अभिभावक अम्बिका बस्नेत केन्द्रिय सदस्यबाट राजिन...     0.0       0.0  0.000000
# टिकट दिएन पार्टीबाट राजीनामा पार्टी अवसरवादी ती...     0.0       0.0  0.000000
# योगी सरकार                                             0.0       0.0  0.000000
# जय महाकाल सरकार                                        0.0       0.0  0.000000
# तालमेल नभएका मिलेन चुनाव लड्न गठबन्धनको                0.0       0.0  0.000000
#
# [91209 rows x 48832 columns]

# %%
filtered_data['len_text'] = filtered_data.clean_tokenized_text.apply(lambda x: len(x.split(" ")))
special_df = filtered_data.sort_values('len_text').loc[[1,2]]
special_df
# Out:
#    Unnamed: 0                   id  \
# 1           1  1601226348013707008
# 1           1  1601226348013707008
# 2           2  1601225158538117120
# 2           2  1601225158538117120
#
#                                                 text  label Unnamed: 3  \
# 1  @KanakManiDixit @Himal_Khabar अब नयाँ जनप्रतिन...      1        NaN
# 1  @KanakManiDixit @Himal_Khabar अब नयाँ जनप्रतिन...      1        NaN
# 2  @damasebijaya च्याखे थापेर करारका जनप्रतिनिधिन...      1        NaN
# 2  @damasebijaya च्याखे थापेर करारका जनप्रतिनिधिन...      1        NaN
#
#                                 clean_tokenized_text  len_text
# 1     जनप्रतिनिधि सर्वोच्च न्यायाधीश महाभियोग हटाउनु         5
# 1     जनप्रतिनिधि सर्वोच्च न्यायाधीश महाभियोग हटाउनु         5
# 2  च्याखे थापेर अत्याचार निजामती पास जनप्रतिनिधि ...        11
# 2  च्याखे थापेर अत्याचार निजामती पास जनप्रतिनिधि ...        11

# %%
tmpdf = tfidf_df.loc[special_df.clean_tokenized_text]
tmpdf = tmpdf[tmpdf.columns[(tmpdf > 0.01).any()]].reset_index()
tmpdf = pd.merge(tmpdf, special_df, on='clean_tokenized_text').drop_duplicates()
tmpdf = tmpdf[[c for c in tmpdf.columns if 'Unnamed' not in c]]
tmpdf
# Out:
#                                 clean_tokenized_text   निजामती    च्याखे  \
# 0     जनप्रतिनिधि सर्वोच्च न्यायाधीश महाभियोग हटाउनु  0.000000  0.000000
# 8  च्याखे थापेर अत्याचार निजामती पास जनप्रतिनिधि ...  0.343676  0.334846
#
#       थापेर    हटाउनु     करार      झुठो  अत्याचार  महाभियोग  न्यायाधीश  \
# 0  0.000000  0.520596  0.00000  0.000000  0.000000  0.477028   0.472018
# 8  0.334846  0.000000  0.32943  0.320601  0.314631  0.000000   0.000000
#
#       बोलेर  सर्वोच्च       पास        पद  जनप्रतिनिधि                   id  \
# 0  0.000000  0.412148  0.000000  0.000000     0.329783  1601226348013707008
# 8  0.286632  0.000000  0.420518  0.215414     0.204805  1601225158538117120
#
#                                                 text  label  len_text
# 0  @KanakManiDixit @Himal_Khabar अब नयाँ जनप्रतिन...      1         5
# 8  @damasebijaya च्याखे थापेर करारका जनप्रतिनिधिन...      1        11

# %%
tmpdf.to_csv('tmp.csv')

# %% [markdown]
# ## Train Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report

# Train Logistic Regression Classifier
classifier = LogisticRegression()
classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred_train = classifier.predict(X_train_tfidf)
y_pred = classifier.predict(X_test_tfidf)


print("Traning Performance")
accuracy = accuracy_score(Y_train, y_pred_train)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_train, y_pred_train)
f1 = f1_score(Y_train, y_pred_train)
recall = recall_score(Y_train, y_pred_train)
confusion = confusion_matrix(Y_train, y_pred_train)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_train, y_pred_train)

print("Classification Report:\n", report)



# Evaluate the Model

print("Testing Performance")
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_test, y_pred)

print("Classification Report:\n", report)
# Out:
# Traning Performance
# Accuracy: 0.8476
# Precision:  0.829012185636505
# F1 score:  0.851882934367049
# Recall score:  0.8760513986684567
# Confusion Matrix:
#   [[29873  6595]
#  [ 4524 31975]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84     36468
#            1       0.83      0.88      0.85     36499
#
#     accuracy                           0.85     72967
#    macro avg       0.85      0.85      0.85     72967
# weighted avg       0.85      0.85      0.85     72967
#
# Testing Performance
# Accuracy: 0.7671
# Precision:  0.751216482037478
# F1 score:  0.7735607675906183
# Recall score:  0.797275024722558
# Confusion Matrix:
#   [[6738 2403]
#  [1845 7256]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.74      0.76      9141
#            1       0.75      0.80      0.77      9101
#
#     accuracy                           0.77     18242
#    macro avg       0.77      0.77      0.77     18242
# weighted avg       0.77      0.77      0.77     18242

# %% [markdown]
# ## Train Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report


# Train Decision Tree Classifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred_train = classifier.predict(X_train_tfidf)
y_pred = classifier.predict(X_test_tfidf)


print("Traning Performance")
accuracy = accuracy_score(Y_train, y_pred_train)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_train, y_pred_train)
f1 = f1_score(Y_train, y_pred_train)
recall = recall_score(Y_train, y_pred_train)
confusion = confusion_matrix(Y_train, y_pred_train)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_train, y_pred_train)

print("Classification Report:\n", report)






# Evaluate the Model

print("Testing Performance")
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_test, y_pred)

print("Classification Report:\n", report)
# Out:
# Traning Performance
# Accuracy: 0.9994
# Precision:  0.9996436208125445
# F1 score:  0.9993559614673116
# Recall score:  0.9990684676292502
# Confusion Matrix:
#   [[36455    13]
#  [   34 36465]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     36468
#            1       1.00      1.00      1.00     36499
#
#     accuracy                           1.00     72967
#    macro avg       1.00      1.00      1.00     72967
# weighted avg       1.00      1.00      1.00     72967
#
# Testing Performance
# Accuracy: 0.7869
# Precision:  0.7542182775772944
# F1 score:  0.7991112948227757
# Recall score:  0.8496868475991649
# Confusion Matrix:
#   [[6621 2520]
#  [1368 7733]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77      9141
#            1       0.75      0.85      0.80      9101
#
#     accuracy                           0.79     18242
#    macro avg       0.79      0.79      0.79     18242
# weighted avg       0.79      0.79      0.79     18242

# %% [markdown]
# ## Train NaiveBayes

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report


# Train Binary Naive Bayes Classifier
classifier = BernoulliNB()
classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred_train = classifier.predict(X_train_tfidf)
y_pred = classifier.predict(X_test_tfidf)


print("Traning Performance")
accuracy = accuracy_score(Y_train, y_pred_train)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_train, y_pred_train)
f1 = f1_score(Y_train, y_pred_train)
recall = recall_score(Y_train, y_pred_train)
confusion = confusion_matrix(Y_train, y_pred_train)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_train, y_pred_train)

print("Classification Report:\n", report)

# Evaluate the Model

print("Testing Performance")
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_test, y_pred)

print("Classification Report:\n", report)
# Out:
# Traning Performance
# Accuracy: 0.8218
# Precision:  0.8111558427799554
# F1 score:  0.8248872129822906
# Recall score:  0.8390914819584098
# Confusion Matrix:
#   [[29338  7130]
#  [ 5873 30626]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82     36468
#            1       0.81      0.84      0.82     36499
#
#     accuracy                           0.82     72967
#    macro avg       0.82      0.82      0.82     72967
# weighted avg       0.82      0.82      0.82     72967
#
# Testing Performance
# Accuracy: 0.7505
# Precision:  0.7369298062903562
# F1 score:  0.7566700529326847
# Recall score:  0.777496978354027
# Confusion Matrix:
#   [[6615 2526]
#  [2025 7076]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74      9141
#            1       0.74      0.78      0.76      9101
#
#     accuracy                           0.75     18242
#    macro avg       0.75      0.75      0.75     18242
# weighted avg       0.75      0.75      0.75     18242

# %% [markdown]
# ## Train Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report


# Train Random Forest Classifier
classifier = RandomForestClassifier(n_estimators=100, random_state=42)
classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred_train = classifier.predict(X_train_tfidf)
y_pred = classifier.predict(X_test_tfidf)


print("Traning Performance")
accuracy = accuracy_score(Y_train, y_pred_train)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_train, y_pred_train)
f1 = f1_score(Y_train, y_pred_train)
recall = recall_score(Y_train, y_pred_train)
confusion = confusion_matrix(Y_train, y_pred_train)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_train, y_pred_train)

print("Classification Report:\n", report)


# Evaluate the Model

print("Testing Performance")
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_test, y_pred)

print("Classification Report:\n", report)
# Out:
# Traning Performance
# Accuracy: 0.9994
# Precision:  0.9993424657534247
# F1 score:  0.9993561555637749
# Recall score:  0.9993698457491986
# Confusion Matrix:
#   [[36444    24]
#  [   23 36476]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     36468
#            1       1.00      1.00      1.00     36499
#
#     accuracy                           1.00     72967
#    macro avg       1.00      1.00      1.00     72967
# weighted avg       1.00      1.00      1.00     72967
#
# Testing Performance
# Accuracy: 0.8170
# Precision:  0.7799261562378547
# F1 score:  0.8278244727478987
# Recall score:  0.8819909900010988
# Confusion Matrix:
#   [[6876 2265]
#  [1074 8027]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80      9141
#            1       0.78      0.88      0.83      9101
#
#     accuracy                           0.82     18242
#    macro avg       0.82      0.82      0.82     18242
# weighted avg       0.82      0.82      0.82     18242

# %% [markdown]
# ## Train SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report


# Train SVM Classifier
classifier = SVC(kernel='linear', C=1.0, random_state=42)
classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred_train = classifier.predict(X_train_tfidf)
y_pred = classifier.predict(X_test_tfidf)


print("Traning Performance")
accuracy = accuracy_score(Y_train, y_pred_train)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_train, y_pred_train)
f1 = f1_score(Y_train, y_pred_train)
recall = recall_score(Y_train, y_pred_train)
confusion = confusion_matrix(Y_train, y_pred_train)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_train, y_pred_train)

print("Classification Report:\n", report)

# Evaluate the Model

print("Testing Performance")
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")


precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_test, y_pred)

print("Classification Report:\n", report)
# Out:
# Traning Performance
# Accuracy: 0.8807
# Precision:  0.8618705410612925
# F1 score:  0.8838128295841399
# Recall score:  0.9069015589468205
# Confusion Matrix:
#   [[31163  5305]
#  [ 3398 33101]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88     36468
#            1       0.86      0.91      0.88     36499
#
#     accuracy                           0.88     72967
#    macro avg       0.88      0.88      0.88     72967
# weighted avg       0.88      0.88      0.88     72967
#
# Testing Performance
# Accuracy: 0.7760
# Precision:  0.7589341045238587
# F1 score:  0.7824096257253901
# Recall score:  0.8073838039775849
# Confusion Matrix:
#   [[6807 2334]
#  [1753 7348]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.74      0.77      9141
#            1       0.76      0.81      0.78      9101
#
#     accuracy                           0.78     18242
#    macro avg       0.78      0.78      0.78     18242
# weighted avg       0.78      0.78      0.78     18242

# %% [markdown]
# ## SVM RBF

# %%
from sklearn.svm import SVC
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report

# Train SVM Classifier
classifier = SVC(kernel='linear', C=1.5, gamma='auto', random_state=42)
classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred = classifier.predict(X_test_tfidf)

# Evaluate the Model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)

report = classification_report(Y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.7788
# Precision:  0.7624326564442603
# F1 score:  0.7848344264917613
# Recall score:  0.8085924623667728
# Confusion Matrix:
#   [[6848 2293]
#  [1742 7359]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.75      0.77      9141
#            1       0.76      0.81      0.78      9101
#
#     accuracy                           0.78     18242
#    macro avg       0.78      0.78      0.78     18242
# weighted avg       0.78      0.78      0.78     18242

# %% [markdown]
# ## KN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report
classifier = KNeighborsClassifier(n_neighbors=5)

classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred = classifier.predict(X_test_tfidf)

# Evaluate the Model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)


report = classification_report(Y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.7939
# Precision:  0.7780901801520358
# F1 score:  0.7989734816082122
# Recall score:  0.8210086803647951
# Confusion Matrix:
#   [[7010 2131]
#  [1629 7472]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79      9141
#            1       0.78      0.82      0.80      9101
#
#     accuracy                           0.79     18242
#    macro avg       0.79      0.79      0.79     18242
# weighted avg       0.79      0.79      0.79     18242

# %% [markdown]
# ## Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report

classifier = GradientBoostingClassifier(n_estimators=100, learning_rate=.05, max_depth=5, random_state=42)


classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred = classifier.predict(X_test_tfidf)

# Evaluate the Model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)


report = classification_report(Y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.6451
# Precision:  0.6105546671155626
# F1 score:  0.6914498141263941
# Recall score:  0.7970552686517965
# Confusion Matrix:
#   [[4514 4627]
#  [1847 7254]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.49      0.58      9141
#            1       0.61      0.80      0.69      9101
#
#     accuracy                           0.65     18242
#    macro avg       0.66      0.65      0.64     18242
# weighted avg       0.66      0.65      0.64     18242

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report

classifier = AdaBoostClassifier(n_estimators=50, learning_rate=0.1, random_state=42)


classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred = classifier.predict(X_test_tfidf)

# Evaluate the Model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)


report = classification_report(Y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.6035
# Precision:  0.564708327559928
# F1 score:  0.6926704907584448
# Recall score:  0.8956158663883089
# Confusion Matrix:
#   [[2858 6283]
#  [ 950 8151]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      0.31      0.44      9141
#            1       0.56      0.90      0.69      9101
#
#     accuracy                           0.60     18242
#    macro avg       0.66      0.60      0.57     18242
# weighted avg       0.66      0.60      0.57     18242

# %% [markdown]
# ## XGBoost

# %%
from xgboost import XGBClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix, accuracy_score, classification_report

classifier = XGBClassifier()

classifier.fit(X_train_tfidf, Y_train)

# Make Predictions
y_pred = classifier.predict(X_test_tfidf)

# Evaluate the Model
accuracy = accuracy_score(Y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
precision = precision_score(Y_test, y_pred)
f1 = f1_score(Y_test, y_pred)
recall = recall_score(Y_test, y_pred)
confusion = confusion_matrix(Y_test, y_pred)
print("Precision: " , precision)
print("F1 score: ",f1)
print("Recall score: ", recall)
print("Confusion Matrix:\n ", confusion)


report = classification_report(Y_test, y_pred)
print("Classification Report:\n", report)
# Out:
# Accuracy: 0.6976
# Precision:  0.6713520749665328
# F1 score:  0.7179303645380644
# Recall score:  0.771453686408087
# Confusion Matrix:
#   [[5704 3437]
#  [2080 7021]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.62      0.67      9141
#            1       0.67      0.77      0.72      9101
#
#     accuracy                           0.70     18242
#    macro avg       0.70      0.70      0.70     18242
# weighted avg       0.70      0.70      0.70     18242

# %%
# just to make sure not run below.
sadgfsadf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-25a6a181ffbd> in <cell line: 2>()
#       1 # just to make sure not run below.
# ----> 2 sadgfsadf
#
# NameError: name 'sadgfsadf' is not defined

# %% [markdown]
# # Using Word2Vec

# %% [markdown]
# ## Logistic Regression

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
from gensim.models import Word2Vec
from gensim.models.doc2vec import TaggedDocument
from nltk.tokenize import word_tokenize
import nltk
from tqdm import tqdm

# Download NLTK resources if not already downloaded
nltk.download('punkt')

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(filtered_data['clean_tokenized_text'],filtered_data['label'], test_size=0.2, random_state=42)

# Tokenize the text using NLTK
tokenized_train = [word_tokenize(text.lower()) for text in tqdm(X_train, desc="Tokenizing Train Data")]
tokenized_test = [word_tokenize(text.lower()) for text in tqdm(X_test, desc="Tokenizing Test Data")]

# Train Word2Vec model
w2v_model = Word2Vec(sentences=tokenized_train, vector_size=10000, window=15, min_count=1, workers=4)

# Function to calculate document vectors using Word2Vec model
def calculate_doc_vector(model, tokenized_text):
    vector_sum = np.zeros(model.vector_size)
    for word in tokenized_text:
        if word in model.wv:
            vector_sum += model.wv[word]
    return vector_sum / len(tokenized_text)

# Create document vectors for training and testing sets
X_train_w2v = np.array([calculate_doc_vector(w2v_model, tokenized_text) for tokenized_text in tqdm(tokenized_train, desc="Creating Train Vectors")])
X_test_w2v = np.array([calculate_doc_vector(w2v_model, tokenized_text) for tokenized_text in tqdm(tokenized_test, desc="Creating Test Vectors")])

# Train a logistic regression classifier
clf = LogisticRegression(random_state=42)
clf.fit(X_train_w2v, y_train)

# Predictions on the test set
y_pred = clf.predict(X_test_w2v)

# Evaluate the model
print(classification_report(y_test, y_pred))
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Train Decision Tree Classifier
clf = DecisionTreeClassifier()
clf.fit(X_train_w2v, y_train)

# Predictions on the test set
y_pred = clf.predict(X_test_w2v)

# Evaluate the model
print(classification_report(y_test, y_pred))
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

# %% [markdown]
# ## naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB

# Train Binary Naive Bayes Classifier
clf = BernoulliNB()
clf.fit(X_train_w2v, y_train)

# Predictions on the test set
y_pred = clf.predict(X_test_w2v)

# Evaluate the model
print(classification_report(y_test, y_pred))
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# Train Random Forest Classifier
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train_w2v, y_train)

# Predictions on the test set
y_pred = clf.predict(X_test_w2v)

# Evaluate the model
print(classification_report(y_test, y_pred))
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC

# Train SVM Classifier
clf = SVC(kernel='linear', C=1.0, random_state=42)
clf.fit(X_train_w2v, y_train)

# Predictions on the test set
y_pred = clf.predict(X_test_w2v)

# Evaluate the model
print(classification_report(y_test, y_pred))
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")

# %% [markdown]
# # Count Vectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# X_train, X_test, X_valid, Y_train, Y_test, Y_valid = data_handler.train_test_split()

vectorizer = CountVectorizer(ngram_range=(1, 3), vocabulary=list(vocab.keys())).fit(list(vocab.keys()))

X = vectorizer.transform(filtered_data['clean_tokenized_text']).toarray()
y = filtered_data['label'].to_numpy()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X.shape, y.shape

# %%
vectorizer.get_feature_names_out()[1000:1005]

# %%
filtered_data.label.unique() # problem yehi ho.... only one label of data is there

# %% [markdown]
# ## MultinomialNB

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Create a CountVectorizer to convert text to a bag-of-words
vectorizer = CountVectorizer()  # You can adjust max_features based on your dataset size

train_data, test_data, train_labels, test_labels = X_train, X_test, y_train, y_test

# Fit and transform on the training data
#train_features = vectorizer.fit_transform(train_data)

# Transform the test data
#test_features = vectorizer.fit_transform(test_data)

# Create a Naive Bayes classifier
classifier = MultinomialNB()

# Train the classifier
classifier.fit(train_data, train_labels)

# Make predictions on the test set
predictions = classifier.predict(test_data)

# Evaluate accuracy
accuracy = accuracy_score(test_labels, predictions)
print(f'Accuracy: {accuracy:.2f}')

# Display classification report and confusion matrix
print('\nClassification Report:')
print(classification_report(test_labels, predictions))

print('\nConfusion Matrix:')
print(confusion_matrix(test_labels, predictions))

# %%
# see now its different?

# %% [markdown]
# ## Train Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression  # or any other classifier you prefer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, recall_score, precision_score

# %%
clf = LogisticRegression(random_state=0).fit(X_train, y_train)

train_score = clf.score(X_train, y_train)
test_score = clf.score(X_test, y_test)


print(f"Train Score: {train_score}, Test Score: {test_score}")

# %%
Y_pred = clf.predict(X_test)
f1 = f1_score(y_test, Y_pred)
recall = recall_score(y_test, Y_pred)
precision = precision_score(y_test, Y_pred)
print(f1)
print(recall)
print(precision)

# %% [markdown]
# ## RandomForest

# %%
# Data Processing
import pandas as pd
import numpy as np

# Modelling
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Tree Visualisation
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz

# %%
rf = RandomForestClassifier(bootstrap=True,criterion='entropy',)
rf.fit(X_train, y_train)

# %%
y_pred = rf.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %%
f1 = f1_score(y_test, y_pred)

recall = recall_score(y_test, y_pred)

precision = precision_score(y_test, y_pred)


print("F1 Score:", f1)
print("Recall:", recall)
print("Precision:", precision)

# %% [markdown]
# ## SVM

# %%
from sklearn import model_selection, svm

# %%
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train, y_train)
# predict labels
predictions_SVM = SVM.predict(X_test)
#get the accuracy
print("Accuracy: ",accuracy_score(predictions_SVM, y_test)*100)

# %%
f1 = f1_score(y_test, predictions_SVM)

recall = recall_score(y_test, predictions_SVM)
precision = precision_score(y_test, predictions_SVM)
print(f1)
print(recall)
print(precision)

# %% [markdown]
# ## NaiveBayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# making predictions on the testing set
y_pred = gnb.predict(X_test)

# %%
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(y_test, y_pred)*100)

# %%
f1 = f1_score(Y_test, y_pred)


recall = recall_score(Y_test, y_pred)


precision = precision_score(Y_test, y_pred)
print(f1)
print(recall)
print(precision)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
clf_gini = DecisionTreeClassifier(criterion='entropy', max_depth=10, random_state=0)
clf_gini.fit(X_train, y_train)

# %%
y_pred_gini = clf_gini.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
